# %%
import os
from Audio_reader import readtf
from getman import getmanlist
import gc
import numpy as np
import pandas as pd
import pickle
from keras.layers import Dense, Input, Dropout,Flatten,MaxPooling1D
from keras.layers import Conv1D, MaxPooling2D,BatchNormalization,Conv2D
from keras.models import Model
from keras.models import Sequential
from keras import optimizers
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras import regularizers

# %%
def check(y):
    if 74 in y:
        return 0 
    #male
    if 1 in y:
        return 1
    #female
    if 2 in y:
        return 2
    #child
    if 3 in y:
        return 3
    return 0

# %%
X = []
Y = [] 
with open("X_list_eval.pickle","rb") as xf:
    X.extend(pickle.load(xf))
with open("Y_list_eval.pickle","rb") as xf:
    Y.extend(pickle.load(xf))
      
with open("X_list.pickle","rb") as xf:
    X.extend(pickle.load(xf))
with open("Y_list.pickle","rb") as xf:
    Y.extend(pickle.load(xf))

X=np.array(X)
Y=np.array(Y)  

X = X.astype('float32')    
X /= 128

# %%
learning_rate=0.0003
#decay=0.000001
momentum=0.99
dropout_rate = 0.25

rglrzr = regularizers.l2(0.0014)

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same',activation='relu',input_shape=X.shape[1:]))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=dropout_rate))

model.add(Conv2D(128, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(Dropout(rate=dropout_rate))



model.add(Conv2D(256, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=dropout_rate))


model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(Dropout(rate=dropout_rate))



model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(Dropout(rate=dropout_rate))




model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(3,activation='softmax'))
model.summary()

optimizer = optimizers.SGD(lr=learning_rate,momentum=momentum)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer, 
              metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_264 (Conv2D)          (None, 10, 128, 64)       640
# _________________________________________________________________
# batch_normalization_262 (Bat (None, 10, 128, 64)       256
# _________________________________________________________________
# max_pooling2d_138 (MaxPoolin (None, 5, 64, 64)         0
# _________________________________________________________________
# dropout_141 (Dropout)        (None, 5, 64, 64)         0
# _________________________________________________________________
# conv2d_265 (Conv2D)          (None, 5, 64, 128)        73856
# _________________________________________________________________
# batch_normalization_263 (Bat (None, 5, 64, 128)        512
# _________________________________________________________________
# max_pooling2d_139 (MaxPoolin (None, 5, 32, 128)        0
# _________________________________________________________________
# dropout_142 (Dropout)        (None, 5, 32, 128)        0
# _________________________________________________________________
# conv2d_266 (Conv2D)          (None, 5, 32, 256)        295168
# _________________________________________________________________
# batch_normalization_264 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# conv2d_267 (Conv2D)          (None, 5, 32, 256)        590080
# _________________________________________________________________
# batch_normalization_265 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# max_pooling2d_140 (MaxPoolin (None, 2, 16, 256)        0
# _________________________________________________________________
# dropout_143 (Dropout)        (None, 2, 16, 256)        0
# _________________________________________________________________
# conv2d_268 (Conv2D)          (None, 2, 16, 512)        1180160
# _________________________________________________________________
# batch_normalization_266 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# conv2d_269 (Conv2D)          (None, 2, 16, 512)        2359808
# _________________________________________________________________
# batch_normalization_267 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# max_pooling2d_141 (MaxPoolin (None, 2, 8, 512)         0
# _________________________________________________________________
# dropout_144 (Dropout)        (None, 2, 8, 512)         0
# _________________________________________________________________
# conv2d_270 (Conv2D)          (None, 2, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_268 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# conv2d_271 (Conv2D)          (None, 2, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_269 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# max_pooling2d_142 (MaxPoolin (None, 2, 4, 512)         0
# _________________________________________________________________
# dropout_145 (Dropout)        (None, 2, 4, 512)         0
# _________________________________________________________________
# flatten_40 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_80 (Dense)             (None, 128)               524416
# _________________________________________________________________
# dense_81 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 9,755,139
# Trainable params: 9,749,635
# Non-trainable params: 5,504
# _________________________________________________________________

# %%
cb=[]

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=3, verbose=0, mode='auto')
early_stopping = EarlyStopping(monitor='acc', min_delta=0, patience=30, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

cb.append(reduce_lr)
cb.append(early_stopping)

# %%
history=model.fit(X, Y,
          batch_size=32,
          epochs=200,
          verbose=2,
          callbacks=cb,
          validation_split=0.3,
          shuffle=True)
# Out:
# Train on 443 samples, validate on 190 samples
# Epoch 1/200
#  - 15s - loss: 1.5416 - acc: 0.5011 - val_loss: 1.4354 - val_acc: 0.2526
# Epoch 2/200
#  - 1s - loss: 1.3991 - acc: 0.4470 - val_loss: 1.3337 - val_acc: 0.5263
# Epoch 3/200
#  - 1s - loss: 1.1997 - acc: 0.5418 - val_loss: 1.5357 - val_acc: 0.5789
# Epoch 4/200
#  - 1s - loss: 1.0217 - acc: 0.5305 - val_loss: 3.8985 - val_acc: 0.5789
# Epoch 5/200
#  - 1s - loss: 0.9514 - acc: 0.6027 - val_loss: 5.0393 - val_acc: 0.5789
# Epoch 6/200
#  - 1s - loss: 0.9183 - acc: 0.5801 - val_loss: 3.0031 - val_acc: 0.5789
# Epoch 7/200
#  - 1s - loss: 0.9120 - acc: 0.5937 - val_loss: 2.6225 - val_acc: 0.5789
# Epoch 8/200
#  - 1s - loss: 0.9019 - acc: 0.5982 - val_loss: 4.2088 - val_acc: 0.5789
# Epoch 9/200
#  - 1s - loss: 0.8615 - acc: 0.6027 - val_loss: 5.3003 - val_acc: 0.5789
# Epoch 10/200
#  - 1s - loss: 0.8696 - acc: 0.6050 - val_loss: 4.3029 - val_acc: 0.5789
# Epoch 11/200
#  - 1s - loss: 0.8342 - acc: 0.6366 - val_loss: 2.7948 - val_acc: 0.5789
# Epoch 12/200
#  - 1s - loss: 0.8151 - acc: 0.6546 - val_loss: 1.7403 - val_acc: 0.5789
# Epoch 13/200
#  - 1s - loss: 0.7813 - acc: 0.6682 - val_loss: 1.4070 - val_acc: 0.5789
# Epoch 14/200
#  - 1s - loss: 0.7877 - acc: 0.6501 - val_loss: 1.3272 - val_acc: 0.5789
# Epoch 15/200
#  - 1s - loss: 0.7279 - acc: 0.6862 - val_loss: 1.3321 - val_acc: 0.5789
# Epoch 16/200
#  - 1s - loss: 0.7158 - acc: 0.6930 - val_loss: 1.2057 - val_acc: 0.5789
# Epoch 17/200
#  - 1s - loss: 0.7036 - acc: 0.6998 - val_loss: 1.1140 - val_acc: 0.5789
# Epoch 18/200
#  - 1s - loss: 0.6545 - acc: 0.7314 - val_loss: 1.0897 - val_acc: 0.5789
# Epoch 19/200
#  - 1s - loss: 0.6584 - acc: 0.7246 - val_loss: 1.1681 - val_acc: 0.5789
# Epoch 20/200
#  - 1s - loss: 0.6277 - acc: 0.7336 - val_loss: 1.2436 - val_acc: 0.5842
# Epoch 21/200
#  - 1s - loss: 0.5949 - acc: 0.7381 - val_loss: 1.2434 - val_acc: 0.5789
# Epoch 22/200
#  - 1s - loss: 0.5462 - acc: 0.7585 - val_loss: 1.1342 - val_acc: 0.5895
# Epoch 23/200
#  - 1s - loss: 0.5536 - acc: 0.7652 - val_loss: 0.9636 - val_acc: 0.6316
# Epoch 24/200
#  - 1s - loss: 0.4916 - acc: 0.7968 - val_loss: 0.9503 - val_acc: 0.6105
# Epoch 25/200
#  - 1s - loss: 0.4586 - acc: 0.8172 - val_loss: 1.0226 - val_acc: 0.6263
# Epoch 26/200
#  - 1s - loss: 0.4741 - acc: 0.8239 - val_loss: 1.0309 - val_acc: 0.6421
# Epoch 27/200
#  - 1s - loss: 0.4143 - acc: 0.8600 - val_loss: 0.9717 - val_acc: 0.6368
# Epoch 28/200
#  - 1s - loss: 0.3842 - acc: 0.8578 - val_loss: 0.8672 - val_acc: 0.6526
# Epoch 29/200
#  - 1s - loss: 0.3710 - acc: 0.8600 - val_loss: 0.8175 - val_acc: 0.6842
# Epoch 30/200
#  - 1s - loss: 0.3506 - acc: 0.8555 - val_loss: 0.8411 - val_acc: 0.6737
# Epoch 31/200
#  - 1s - loss: 0.3321 - acc: 0.8623 - val_loss: 0.9587 - val_acc: 0.6368
# Epoch 32/200
#  - 1s - loss: 0.2902 - acc: 0.8871 - val_loss: 0.9609 - val_acc: 0.6316
# Epoch 33/200
#  - 1s - loss: 0.2818 - acc: 0.8894 - val_loss: 0.9426 - val_acc: 0.6632
# Epoch 34/200
#  - 1s - loss: 0.2361 - acc: 0.8962 - val_loss: 0.9210 - val_acc: 0.6789
# Epoch 35/200
#  - 1s - loss: 0.2274 - acc: 0.9210 - val_loss: 0.9431 - val_acc: 0.6684
# Epoch 36/200
#  - 1s - loss: 0.2224 - acc: 0.9029 - val_loss: 0.9556 - val_acc: 0.6737
# Epoch 37/200
#  - 1s - loss: 0.1906 - acc: 0.9368 - val_loss: 0.9314 - val_acc: 0.6895
# Epoch 38/200
#  - 1s - loss: 0.1630 - acc: 0.9481 - val_loss: 0.9796 - val_acc: 0.7000
# Epoch 39/200
#  - 1s - loss: 0.1638 - acc: 0.9571 - val_loss: 1.0094 - val_acc: 0.6842
# Epoch 40/200
#  - 1s - loss: 0.1518 - acc: 0.9436 - val_loss: 1.0349 - val_acc: 0.6789
# Epoch 41/200
#  - 1s - loss: 0.1306 - acc: 0.9481 - val_loss: 1.0503 - val_acc: 0.6684
# Epoch 42/200
#  - 1s - loss: 0.1371 - acc: 0.9571 - val_loss: 1.0327 - val_acc: 0.6789
# Epoch 43/200
#  - 1s - loss: 0.1652 - acc: 0.9458 - val_loss: 1.0099 - val_acc: 0.7053
# Epoch 44/200
#  - 1s - loss: 0.1013 - acc: 0.9729 - val_loss: 1.0197 - val_acc: 0.7158
# Epoch 45/200
#  - 1s - loss: 0.0972 - acc: 0.9639 - val_loss: 1.0433 - val_acc: 0.7158
# Epoch 46/200
#  - 1s - loss: 0.0835 - acc: 0.9684 - val_loss: 1.0698 - val_acc: 0.7105
# Epoch 47/200
#  - 1s - loss: 0.1048 - acc: 0.9616 - val_loss: 1.0971 - val_acc: 0.7053
# Epoch 48/200
#  - 1s - loss: 0.0917 - acc: 0.9661 - val_loss: 1.1179 - val_acc: 0.6947
# Epoch 49/200
#  - 1s - loss: 0.1008 - acc: 0.9661 - val_loss: 1.1303 - val_acc: 0.7000
# Epoch 50/200
#  - 1s - loss: 0.0774 - acc: 0.9774 - val_loss: 1.1370 - val_acc: 0.7211
# Epoch 51/200
#  - 1s - loss: 0.0719 - acc: 0.9774 - val_loss: 1.1410 - val_acc: 0.7158
# Epoch 52/200
#  - 1s - loss: 0.0683 - acc: 0.9797 - val_loss: 1.1444 - val_acc: 0.7158
# Epoch 53/200
#  - 1s - loss: 0.0633 - acc: 0.9842 - val_loss: 1.1517 - val_acc: 0.7211
# Epoch 54/200
#  - 1s - loss: 0.0617 - acc: 0.9729 - val_loss: 1.1613 - val_acc: 0.7105
# Epoch 55/200
#  - 1s - loss: 0.0759 - acc: 0.9774 - val_loss: 1.1732 - val_acc: 0.7158
# Epoch 56/200
#  - 1s - loss: 0.0567 - acc: 0.9887 - val_loss: 1.1852 - val_acc: 0.7158
# Epoch 57/200
#  - 1s - loss: 0.0593 - acc: 0.9887 - val_loss: 1.1970 - val_acc: 0.7158
# Epoch 58/200
#  - 1s - loss: 0.0727 - acc: 0.9774 - val_loss: 1.2088 - val_acc: 0.7211
# Epoch 59/200
#  - 1s - loss: 0.0630 - acc: 0.9797 - val_loss: 1.2211 - val_acc: 0.7211
# Epoch 60/200
#  - 1s - loss: 0.0444 - acc: 0.9910 - val_loss: 1.2334 - val_acc: 0.7158
# Epoch 61/200
#  - 1s - loss: 0.0420 - acc: 0.9910 - val_loss: 1.2460 - val_acc: 0.7158
# Epoch 62/200
#  - 1s - loss: 0.0589 - acc: 0.9842 - val_loss: 1.2541 - val_acc: 0.7158
# Epoch 63/200
#  - 1s - loss: 0.0592 - acc: 0.9842 - val_loss: 1.2611 - val_acc: 0.7105
# Epoch 64/200
#  - 1s - loss: 0.0460 - acc: 0.9910 - val_loss: 1.2656 - val_acc: 0.7158
# Epoch 65/200
#  - 1s - loss: 0.0426 - acc: 0.9955 - val_loss: 1.2690 - val_acc: 0.7211
# Epoch 66/200
#  - 1s - loss: 0.0611 - acc: 0.9819 - val_loss: 1.2718 - val_acc: 0.7211
# Epoch 67/200
#  - 1s - loss: 0.0549 - acc: 0.9865 - val_loss: 1.2758 - val_acc: 0.7211
# Epoch 68/200
#  - 1s - loss: 0.0562 - acc: 0.9887 - val_loss: 1.2818 - val_acc: 0.7158
# Epoch 69/200
#  - 1s - loss: 0.0572 - acc: 0.9797 - val_loss: 1.2870 - val_acc: 0.7158
# Epoch 70/200
#  - 1s - loss: 0.0511 - acc: 0.9865 - val_loss: 1.2900 - val_acc: 0.7158
# Epoch 71/200
#  - 1s - loss: 0.0499 - acc: 0.9887 - val_loss: 1.2911 - val_acc: 0.7211
# Epoch 72/200
#  - 1s - loss: 0.0391 - acc: 0.9887 - val_loss: 1.2920 - val_acc: 0.7263
# Epoch 73/200
#  - 1s - loss: 0.0596 - acc: 0.9797 - val_loss: 1.2924 - val_acc: 0.7263
# Epoch 74/200
#  - 1s - loss: 0.0536 - acc: 0.9865 - val_loss: 1.2930 - val_acc: 0.7263
# Epoch 75/200
#  - 1s - loss: 0.0432 - acc: 0.9910 - val_loss: 1.2934 - val_acc: 0.7316
# Epoch 76/200
#  - 1s - loss: 0.0457 - acc: 0.9910 - val_loss: 1.2958 - val_acc: 0.7316
# Epoch 77/200
#  - 1s - loss: 0.0520 - acc: 0.9842 - val_loss: 1.2972 - val_acc: 0.7316
# Epoch 78/200
#  - 1s - loss: 0.0488 - acc: 0.9842 - val_loss: 1.2977 - val_acc: 0.7316
# Epoch 79/200
#  - 1s - loss: 0.0623 - acc: 0.9774 - val_loss: 1.2986 - val_acc: 0.7316
# Epoch 80/200
#  - 1s - loss: 0.0447 - acc: 0.9932 - val_loss: 1.3000 - val_acc: 0.7316
# Epoch 81/200
#  - 1s - loss: 0.0449 - acc: 0.9865 - val_loss: 1.3011 - val_acc: 0.7316
# Epoch 82/200
#  - 1s - loss: 0.0485 - acc: 0.9865 - val_loss: 1.3020 - val_acc: 0.7316
# Epoch 83/200
#  - 1s - loss: 0.0457 - acc: 0.9910 - val_loss: 1.3037 - val_acc: 0.7316
# Epoch 84/200
#  - 1s - loss: 0.0443 - acc: 0.9842 - val_loss: 1.3051 - val_acc: 0.7263
# Epoch 85/200
#  - 1s - loss: 0.0361 - acc: 0.9955 - val_loss: 1.3055 - val_acc: 0.7263
# Epoch 86/200
#  - 1s - loss: 0.0457 - acc: 0.9819 - val_loss: 1.3060 - val_acc: 0.7263
# Epoch 87/200
#  - 1s - loss: 0.0591 - acc: 0.9865 - val_loss: 1.3071 - val_acc: 0.7263
# Epoch 88/200
#  - 1s - loss: 0.0290 - acc: 0.9977 - val_loss: 1.3085 - val_acc: 0.7263
# Epoch 89/200
#  - 1s - loss: 0.0574 - acc: 0.9819 - val_loss: 1.3090 - val_acc: 0.7263
# Epoch 90/200
#  - 1s - loss: 0.0595 - acc: 0.9819 - val_loss: 1.3106 - val_acc: 0.7263
# Epoch 91/200
#  - 1s - loss: 0.0439 - acc: 0.9932 - val_loss: 1.3110 - val_acc: 0.7263
# Epoch 92/200
#  - 1s - loss: 0.0584 - acc: 0.9797 - val_loss: 1.3116 - val_acc: 0.7263
# Epoch 93/200
#  - 1s - loss: 0.0439 - acc: 0.9887 - val_loss: 1.3120 - val_acc: 0.7263
# Epoch 94/200
#  - 1s - loss: 0.0484 - acc: 0.9842 - val_loss: 1.3130 - val_acc: 0.7316
# Epoch 95/200
#  - 1s - loss: 0.0430 - acc: 0.9887 - val_loss: 1.3135 - val_acc: 0.7316
# Epoch 96/200
#  - 1s - loss: 0.0482 - acc: 0.9865 - val_loss: 1.3143 - val_acc: 0.7316
# Epoch 97/200
#  - 1s - loss: 0.0466 - acc: 0.9910 - val_loss: 1.3148 - val_acc: 0.7316
# Epoch 98/200
#  - 1s - loss: 0.0457 - acc: 0.9910 - val_loss: 1.3145 - val_acc: 0.7316
# Epoch 99/200
#  - 1s - loss: 0.0368 - acc: 0.9910 - val_loss: 1.3149 - val_acc: 0.7316
# Epoch 100/200
#  - 1s - loss: 0.0543 - acc: 0.9797 - val_loss: 1.3149 - val_acc: 0.7316
# Epoch 101/200
#  - 1s - loss: 0.0462 - acc: 0.9910 - val_loss: 1.3149 - val_acc: 0.7368
# Epoch 102/200
#  - 1s - loss: 0.0362 - acc: 0.9910 - val_loss: 1.3147 - val_acc: 0.7368
# Epoch 103/200
#  - 1s - loss: 0.0459 - acc: 0.9865 - val_loss: 1.3141 - val_acc: 0.7368
# Epoch 104/200
#  - 1s - loss: 0.0352 - acc: 0.9932 - val_loss: 1.3148 - val_acc: 0.7368
# Epoch 105/200
#  - 1s - loss: 0.0447 - acc: 0.9932 - val_loss: 1.3152 - val_acc: 0.7368
# Epoch 106/200
#  - 1s - loss: 0.0363 - acc: 0.9932 - val_loss: 1.3155 - val_acc: 0.7368
# Epoch 107/200
#  - 1s - loss: 0.0571 - acc: 0.9842 - val_loss: 1.3146 - val_acc: 0.7368
# Epoch 108/200
#  - 1s - loss: 0.0368 - acc: 0.9910 - val_loss: 1.3140 - val_acc: 0.7368
# Epoch 109/200
#  - 1s - loss: 0.0318 - acc: 0.9910 - val_loss: 1.3139 - val_acc: 0.7368
# Epoch 110/200
#  - 1s - loss: 0.0354 - acc: 0.9887 - val_loss: 1.3142 - val_acc: 0.7368
# Epoch 111/200
#  - 1s - loss: 0.0405 - acc: 0.9932 - val_loss: 1.3146 - val_acc: 0.7368
# Epoch 112/200
#  - 1s - loss: 0.0486 - acc: 0.9842 - val_loss: 1.3146 - val_acc: 0.7368
# Epoch 113/200
#  - 1s - loss: 0.0386 - acc: 0.9887 - val_loss: 1.3139 - val_acc: 0.7368
# Epoch 114/200
#  - 1s - loss: 0.0416 - acc: 0.9932 - val_loss: 1.3139 - val_acc: 0.7368
# Epoch 115/200
#  - 1s - loss: 0.0478 - acc: 0.9865 - val_loss: 1.3138 - val_acc: 0.7368
# Epoch 116/200
#  - 1s - loss: 0.0357 - acc: 0.9887 - val_loss: 1.3135 - val_acc: 0.7368
# Epoch 117/200
#  - 1s - loss: 0.0485 - acc: 0.9865 - val_loss: 1.3136 - val_acc: 0.7368
# Epoch 118/200
#  - 1s - loss: 0.0504 - acc: 0.9842 - val_loss: 1.3141 - val_acc: 0.7368

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
