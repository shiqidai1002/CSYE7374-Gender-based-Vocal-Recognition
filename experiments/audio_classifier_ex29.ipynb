# %%
import os
from Audio_reader import readtf
from getman import getmanlist
import gc
import numpy as np
import pandas as pd
import pickle
from keras.layers import Dense, Input, Dropout,Flatten,MaxPooling1D,SpatialDropout2D
from keras.layers import Conv1D, MaxPooling2D,BatchNormalization,Conv2D
from keras.models import Model
from keras.models import Sequential
from keras import optimizers
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras import regularizers

# %%
def check(y):
    if 74 in y:
        return 0 
    #male
    if 1 in y:
        return 1
    #female
    if 2 in y:
        return 2
    #child
    if 3 in y:
        return 3
    return 0

# %%
X = []
Y = [] 
with open("X_list_eval.pickle","rb") as xf:
    X.extend(pickle.load(xf))
with open("Y_list_eval.pickle","rb") as xf:
    Y.extend(pickle.load(xf))
      
with open("X_list.pickle","rb") as xf:
    X.extend(pickle.load(xf))
with open("Y_list.pickle","rb") as xf:
    Y.extend(pickle.load(xf))

X=np.array(X)
Y=np.array(Y)  

X = X.astype('float32')    
X /= 128

# %%
learning_rate=0.0003
#decay=0.000001
momentum=0.99
dropout_rate = 0.35

rglrzr = regularizers.l2(0.0017)

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same',activation='relu',input_shape=X.shape[1:]))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=dropout_rate))

model.add(Conv2D(128, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(Dropout(rate=dropout_rate))



model.add(Conv2D(256, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=dropout_rate))


model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(Dropout(rate=dropout_rate))



model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(Dropout(rate=dropout_rate))




model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(3,activation='softmax'))
model.summary()

optimizer = optimizers.SGD(lr=learning_rate,momentum=momentum)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer, 
              metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_288 (Conv2D)          (None, 10, 128, 64)       640
# _________________________________________________________________
# batch_normalization_286 (Bat (None, 10, 128, 64)       256
# _________________________________________________________________
# max_pooling2d_153 (MaxPoolin (None, 5, 64, 64)         0
# _________________________________________________________________
# dropout_156 (Dropout)        (None, 5, 64, 64)         0
# _________________________________________________________________
# conv2d_289 (Conv2D)          (None, 5, 64, 128)        73856
# _________________________________________________________________
# batch_normalization_287 (Bat (None, 5, 64, 128)        512
# _________________________________________________________________
# max_pooling2d_154 (MaxPoolin (None, 5, 32, 128)        0
# _________________________________________________________________
# dropout_157 (Dropout)        (None, 5, 32, 128)        0
# _________________________________________________________________
# conv2d_290 (Conv2D)          (None, 5, 32, 256)        295168
# _________________________________________________________________
# batch_normalization_288 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# conv2d_291 (Conv2D)          (None, 5, 32, 256)        590080
# _________________________________________________________________
# batch_normalization_289 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# max_pooling2d_155 (MaxPoolin (None, 2, 16, 256)        0
# _________________________________________________________________
# dropout_158 (Dropout)        (None, 2, 16, 256)        0
# _________________________________________________________________
# conv2d_292 (Conv2D)          (None, 2, 16, 512)        1180160
# _________________________________________________________________
# batch_normalization_290 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# conv2d_293 (Conv2D)          (None, 2, 16, 512)        2359808
# _________________________________________________________________
# batch_normalization_291 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# max_pooling2d_156 (MaxPoolin (None, 2, 8, 512)         0
# _________________________________________________________________
# dropout_159 (Dropout)        (None, 2, 8, 512)         0
# _________________________________________________________________
# conv2d_294 (Conv2D)          (None, 2, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_292 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# conv2d_295 (Conv2D)          (None, 2, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_293 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# max_pooling2d_157 (MaxPoolin (None, 2, 4, 512)         0
# _________________________________________________________________
# dropout_160 (Dropout)        (None, 2, 4, 512)         0
# _________________________________________________________________
# flatten_43 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_86 (Dense)             (None, 128)               524416
# _________________________________________________________________
# dense_87 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 9,755,139
# Trainable params: 9,749,635
# Non-trainable params: 5,504
# _________________________________________________________________

# %%
cb=[]

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=3, verbose=0, mode='auto')
early_stopping = EarlyStopping(monitor='acc', min_delta=0, patience=30, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

cb.append(reduce_lr)
cb.append(early_stopping)

# %%
history=model.fit(X, Y,
          batch_size=32,
          epochs=200,
          verbose=2,
          callbacks=cb,
          validation_split=0.3,
          shuffle=True)
# Out:
# Train on 443 samples, validate on 190 samples
# Epoch 1/200
#  - 17s - loss: 1.7533 - acc: 0.4673 - val_loss: 1.4344 - val_acc: 0.2526
# Epoch 2/200
#  - 1s - loss: 1.6270 - acc: 0.4379 - val_loss: 1.3893 - val_acc: 0.3053
# Epoch 3/200
#  - 1s - loss: 1.2561 - acc: 0.5553 - val_loss: 1.2002 - val_acc: 0.2579
# Epoch 4/200
#  - 1s - loss: 1.0630 - acc: 0.4831 - val_loss: 1.0456 - val_acc: 0.5789
# Epoch 5/200
#  - 1s - loss: 0.9594 - acc: 0.5937 - val_loss: 1.9798 - val_acc: 0.5789
# Epoch 6/200
#  - 1s - loss: 0.9460 - acc: 0.6095 - val_loss: 1.6447 - val_acc: 0.1947
# Epoch 7/200
#  - 1s - loss: 0.9267 - acc: 0.5914 - val_loss: 1.4793 - val_acc: 0.2000
# Epoch 8/200
#  - 1s - loss: 0.9075 - acc: 0.5847 - val_loss: 1.1828 - val_acc: 0.5789
# Epoch 9/200
#  - 1s - loss: 0.8952 - acc: 0.6117 - val_loss: 1.0340 - val_acc: 0.5789
# Epoch 10/200
#  - 1s - loss: 0.8849 - acc: 0.6005 - val_loss: 1.2714 - val_acc: 0.3421
# Epoch 11/200
#  - 1s - loss: 0.8854 - acc: 0.6230 - val_loss: 1.2261 - val_acc: 0.3053
# Epoch 12/200
#  - 1s - loss: 0.8719 - acc: 0.6163 - val_loss: 1.1776 - val_acc: 0.5789
# Epoch 13/200
#  - 1s - loss: 0.8628 - acc: 0.6366 - val_loss: 1.4436 - val_acc: 0.5632
# Epoch 14/200
#  - 1s - loss: 0.8327 - acc: 0.6321 - val_loss: 1.4535 - val_acc: 0.5632
# Epoch 15/200
#  - 1s - loss: 0.8474 - acc: 0.6185 - val_loss: 1.3113 - val_acc: 0.5526
# Epoch 16/200
#  - 1s - loss: 0.8319 - acc: 0.6298 - val_loss: 1.1575 - val_acc: 0.5474
# Epoch 17/200
#  - 1s - loss: 0.8176 - acc: 0.6388 - val_loss: 1.0409 - val_acc: 0.5579
# Epoch 18/200
#  - 1s - loss: 0.8091 - acc: 0.6479 - val_loss: 0.9849 - val_acc: 0.5737
# Epoch 19/200
#  - 1s - loss: 0.7815 - acc: 0.6501 - val_loss: 1.0161 - val_acc: 0.5947
# Epoch 20/200
#  - 1s - loss: 0.7822 - acc: 0.6840 - val_loss: 1.0769 - val_acc: 0.5684
# Epoch 21/200
#  - 1s - loss: 0.7696 - acc: 0.6569 - val_loss: 1.1104 - val_acc: 0.5579
# Epoch 22/200
#  - 1s - loss: 0.7605 - acc: 0.6772 - val_loss: 1.1068 - val_acc: 0.5474
# Epoch 23/200
#  - 1s - loss: 0.7649 - acc: 0.6637 - val_loss: 1.1429 - val_acc: 0.5316
# Epoch 24/200
#  - 1s - loss: 0.7670 - acc: 0.6682 - val_loss: 1.1525 - val_acc: 0.5158
# Epoch 25/200
#  - 1s - loss: 0.7245 - acc: 0.6885 - val_loss: 1.1433 - val_acc: 0.5211
# Epoch 26/200
#  - 1s - loss: 0.7174 - acc: 0.7020 - val_loss: 1.1346 - val_acc: 0.4947
# Epoch 27/200
#  - 1s - loss: 0.7178 - acc: 0.7020 - val_loss: 1.1531 - val_acc: 0.4842
# Epoch 28/200
#  - 1s - loss: 0.7009 - acc: 0.6998 - val_loss: 1.1781 - val_acc: 0.4684
# Epoch 29/200
#  - 1s - loss: 0.7274 - acc: 0.6953 - val_loss: 1.1533 - val_acc: 0.4737
# Epoch 30/200
#  - 1s - loss: 0.7034 - acc: 0.6998 - val_loss: 1.1308 - val_acc: 0.5000
# Epoch 31/200
#  - 1s - loss: 0.6828 - acc: 0.6998 - val_loss: 1.1314 - val_acc: 0.5053
# Epoch 32/200
#  - 1s - loss: 0.6704 - acc: 0.7291 - val_loss: 1.1574 - val_acc: 0.4842
# Epoch 33/200
#  - 1s - loss: 0.6612 - acc: 0.7111 - val_loss: 1.1773 - val_acc: 0.4842
# Epoch 34/200
#  - 1s - loss: 0.6545 - acc: 0.7223 - val_loss: 1.1555 - val_acc: 0.4895
# Epoch 35/200
#  - 1s - loss: 0.6384 - acc: 0.7517 - val_loss: 1.0784 - val_acc: 0.4947
# Epoch 36/200
#  - 1s - loss: 0.6216 - acc: 0.7427 - val_loss: 0.9981 - val_acc: 0.5211
# Epoch 37/200
#  - 1s - loss: 0.6068 - acc: 0.7336 - val_loss: 0.9420 - val_acc: 0.5526
# Epoch 38/200
#  - 1s - loss: 0.5938 - acc: 0.7607 - val_loss: 0.9285 - val_acc: 0.5632
# Epoch 39/200
#  - 1s - loss: 0.6344 - acc: 0.7336 - val_loss: 0.9394 - val_acc: 0.5632
# Epoch 40/200
#  - 1s - loss: 0.5829 - acc: 0.7517 - val_loss: 0.9809 - val_acc: 0.5421
# Epoch 41/200
#  - 1s - loss: 0.5988 - acc: 0.7404 - val_loss: 1.0150 - val_acc: 0.5368
# Epoch 42/200
#  - 1s - loss: 0.5679 - acc: 0.7517 - val_loss: 1.0394 - val_acc: 0.5474
# Epoch 43/200
#  - 1s - loss: 0.5430 - acc: 0.7585 - val_loss: 1.0406 - val_acc: 0.5421
# Epoch 44/200
#  - 1s - loss: 0.5637 - acc: 0.7607 - val_loss: 1.0083 - val_acc: 0.5684
# Epoch 45/200
#  - 1s - loss: 0.5772 - acc: 0.7810 - val_loss: 0.9829 - val_acc: 0.5895
# Epoch 46/200
#  - 1s - loss: 0.5495 - acc: 0.7765 - val_loss: 0.9688 - val_acc: 0.5789
# Epoch 47/200
#  - 1s - loss: 0.5426 - acc: 0.7788 - val_loss: 0.9539 - val_acc: 0.6000
# Epoch 48/200
#  - 1s - loss: 0.5392 - acc: 0.7810 - val_loss: 0.9389 - val_acc: 0.6053
# Epoch 49/200
#  - 1s - loss: 0.5195 - acc: 0.7765 - val_loss: 0.9317 - val_acc: 0.6053
# Epoch 50/200
#  - 1s - loss: 0.5235 - acc: 0.7991 - val_loss: 0.9174 - val_acc: 0.6053
# Epoch 51/200
#  - 1s - loss: 0.5034 - acc: 0.7991 - val_loss: 0.9017 - val_acc: 0.6053
# Epoch 52/200
#  - 1s - loss: 0.4965 - acc: 0.7878 - val_loss: 0.8913 - val_acc: 0.6105
# Epoch 53/200
#  - 1s - loss: 0.4973 - acc: 0.8194 - val_loss: 0.8802 - val_acc: 0.6316
# Epoch 54/200
#  - 1s - loss: 0.5104 - acc: 0.7968 - val_loss: 0.8710 - val_acc: 0.6316
# Epoch 55/200
#  - 1s - loss: 0.5114 - acc: 0.7968 - val_loss: 0.8695 - val_acc: 0.6263
# Epoch 56/200
#  - 1s - loss: 0.5223 - acc: 0.8036 - val_loss: 0.8698 - val_acc: 0.6316
# Epoch 57/200
#  - 1s - loss: 0.4846 - acc: 0.8262 - val_loss: 0.8764 - val_acc: 0.6316
# Epoch 58/200
#  - 1s - loss: 0.4922 - acc: 0.7991 - val_loss: 0.8851 - val_acc: 0.6211
# Epoch 59/200
#  - 1s - loss: 0.4806 - acc: 0.7878 - val_loss: 0.8945 - val_acc: 0.6158
# Epoch 60/200
#  - 1s - loss: 0.4998 - acc: 0.7878 - val_loss: 0.9045 - val_acc: 0.6053
# Epoch 61/200
#  - 1s - loss: 0.4870 - acc: 0.8036 - val_loss: 0.9069 - val_acc: 0.6105
# Epoch 62/200
#  - 1s - loss: 0.4643 - acc: 0.8149 - val_loss: 0.9060 - val_acc: 0.6105
# Epoch 63/200
#  - 1s - loss: 0.4715 - acc: 0.8036 - val_loss: 0.9081 - val_acc: 0.6053
# Epoch 64/200
#  - 1s - loss: 0.4483 - acc: 0.8330 - val_loss: 0.9125 - val_acc: 0.6105
# Epoch 65/200
#  - 1s - loss: 0.4923 - acc: 0.7991 - val_loss: 0.9138 - val_acc: 0.6053
# Epoch 66/200
#  - 1s - loss: 0.4605 - acc: 0.8217 - val_loss: 0.9130 - val_acc: 0.6105
# Epoch 67/200
#  - 1s - loss: 0.4764 - acc: 0.8194 - val_loss: 0.9099 - val_acc: 0.6105
# Epoch 68/200
#  - 1s - loss: 0.4321 - acc: 0.8284 - val_loss: 0.9055 - val_acc: 0.6211
# Epoch 69/200
#  - 1s - loss: 0.4870 - acc: 0.8172 - val_loss: 0.9041 - val_acc: 0.6211
# Epoch 70/200
#  - 1s - loss: 0.4468 - acc: 0.8194 - val_loss: 0.9017 - val_acc: 0.6211
# Epoch 71/200
#  - 1s - loss: 0.4595 - acc: 0.8014 - val_loss: 0.8989 - val_acc: 0.6263
# Epoch 72/200
#  - 1s - loss: 0.4318 - acc: 0.8262 - val_loss: 0.8981 - val_acc: 0.6263
# Epoch 73/200
#  - 1s - loss: 0.4624 - acc: 0.8262 - val_loss: 0.8959 - val_acc: 0.6316
# Epoch 74/200
#  - 1s - loss: 0.4481 - acc: 0.8262 - val_loss: 0.8942 - val_acc: 0.6316
# Epoch 75/200
#  - 1s - loss: 0.4522 - acc: 0.7991 - val_loss: 0.8940 - val_acc: 0.6368
# Epoch 76/200
#  - 1s - loss: 0.4227 - acc: 0.8533 - val_loss: 0.8942 - val_acc: 0.6421
# Epoch 77/200
#  - 1s - loss: 0.4340 - acc: 0.8442 - val_loss: 0.8962 - val_acc: 0.6368
# Epoch 78/200
#  - 1s - loss: 0.4345 - acc: 0.8194 - val_loss: 0.8994 - val_acc: 0.6368
# Epoch 79/200
#  - 1s - loss: 0.4500 - acc: 0.8352 - val_loss: 0.9016 - val_acc: 0.6368
# Epoch 80/200
#  - 1s - loss: 0.4204 - acc: 0.8307 - val_loss: 0.9034 - val_acc: 0.6368
# Epoch 81/200
#  - 1s - loss: 0.4463 - acc: 0.8330 - val_loss: 0.9028 - val_acc: 0.6368
# Epoch 82/200
#  - 1s - loss: 0.4280 - acc: 0.8397 - val_loss: 0.9033 - val_acc: 0.6421
# Epoch 83/200
#  - 1s - loss: 0.4280 - acc: 0.8397 - val_loss: 0.9054 - val_acc: 0.6368
# Epoch 84/200
#  - 1s - loss: 0.3991 - acc: 0.8600 - val_loss: 0.9074 - val_acc: 0.6316
# Epoch 85/200
#  - 1s - loss: 0.4327 - acc: 0.8149 - val_loss: 0.9090 - val_acc: 0.6211
# Epoch 86/200
#  - 1s - loss: 0.4491 - acc: 0.8172 - val_loss: 0.9097 - val_acc: 0.6316
# Epoch 87/200
#  - 1s - loss: 0.4157 - acc: 0.8397 - val_loss: 0.9113 - val_acc: 0.6316
# Epoch 88/200
#  - 1s - loss: 0.4345 - acc: 0.8149 - val_loss: 0.9121 - val_acc: 0.6316
# Epoch 89/200
#  - 1s - loss: 0.4399 - acc: 0.8375 - val_loss: 0.9119 - val_acc: 0.6368
# Epoch 90/200
#  - 1s - loss: 0.3986 - acc: 0.8488 - val_loss: 0.9115 - val_acc: 0.6368
# Epoch 91/200
#  - 1s - loss: 0.4044 - acc: 0.8646 - val_loss: 0.9109 - val_acc: 0.6421
# Epoch 92/200
#  - 1s - loss: 0.4186 - acc: 0.8307 - val_loss: 0.9116 - val_acc: 0.6316
# Epoch 93/200
#  - 1s - loss: 0.4521 - acc: 0.8284 - val_loss: 0.9109 - val_acc: 0.6316
# Epoch 94/200
#  - 1s - loss: 0.3955 - acc: 0.8442 - val_loss: 0.9090 - val_acc: 0.6368
# Epoch 95/200
#  - 1s - loss: 0.4233 - acc: 0.8555 - val_loss: 0.9069 - val_acc: 0.6368
# Epoch 96/200
#  - 1s - loss: 0.4222 - acc: 0.8239 - val_loss: 0.9060 - val_acc: 0.6368
# Epoch 97/200
#  - 1s - loss: 0.4026 - acc: 0.8488 - val_loss: 0.9045 - val_acc: 0.6368
# Epoch 98/200
#  - 1s - loss: 0.4048 - acc: 0.8442 - val_loss: 0.9037 - val_acc: 0.6421
# Epoch 99/200
#  - 1s - loss: 0.4485 - acc: 0.8262 - val_loss: 0.9015 - val_acc: 0.6474
# Epoch 100/200
#  - 1s - loss: 0.4191 - acc: 0.8668 - val_loss: 0.9010 - val_acc: 0.6474
# Epoch 101/200
#  - 1s - loss: 0.4011 - acc: 0.8284 - val_loss: 0.9008 - val_acc: 0.6474
# Epoch 102/200
#  - 1s - loss: 0.3896 - acc: 0.8375 - val_loss: 0.9017 - val_acc: 0.6474
# Epoch 103/200
#  - 1s - loss: 0.4209 - acc: 0.8420 - val_loss: 0.9003 - val_acc: 0.6474
# Epoch 104/200
#  - 1s - loss: 0.4135 - acc: 0.8397 - val_loss: 0.9011 - val_acc: 0.6474
# Epoch 105/200
#  - 1s - loss: 0.4258 - acc: 0.8352 - val_loss: 0.9009 - val_acc: 0.6474
# Epoch 106/200
#  - 1s - loss: 0.4023 - acc: 0.8510 - val_loss: 0.8996 - val_acc: 0.6474
# Epoch 107/200
#  - 1s - loss: 0.4238 - acc: 0.8420 - val_loss: 0.8993 - val_acc: 0.6474
# Epoch 108/200
#  - 1s - loss: 0.4340 - acc: 0.8442 - val_loss: 0.8991 - val_acc: 0.6474
# Epoch 109/200
#  - 1s - loss: 0.4251 - acc: 0.8352 - val_loss: 0.8991 - val_acc: 0.6474
# Epoch 110/200
#  - 1s - loss: 0.4373 - acc: 0.8330 - val_loss: 0.8996 - val_acc: 0.6474
# Epoch 111/200
#  - 1s - loss: 0.4173 - acc: 0.8352 - val_loss: 0.8998 - val_acc: 0.6474
# Epoch 112/200
#  - 1s - loss: 0.4207 - acc: 0.8488 - val_loss: 0.9005 - val_acc: 0.6474
# Epoch 113/200
#  - 1s - loss: 0.4141 - acc: 0.8194 - val_loss: 0.9007 - val_acc: 0.6474
# Epoch 114/200
#  - 1s - loss: 0.4266 - acc: 0.8284 - val_loss: 0.9012 - val_acc: 0.6474
# Epoch 115/200
#  - 1s - loss: 0.4131 - acc: 0.8307 - val_loss: 0.9008 - val_acc: 0.6474
# Epoch 116/200
#  - 1s - loss: 0.4212 - acc: 0.8352 - val_loss: 0.9016 - val_acc: 0.6474
# Epoch 117/200
#  - 1s - loss: 0.3955 - acc: 0.8600 - val_loss: 0.9013 - val_acc: 0.6474
# Epoch 118/200
#  - 1s - loss: 0.4462 - acc: 0.8262 - val_loss: 0.9028 - val_acc: 0.6421
# Epoch 119/200
#  - 1s - loss: 0.4175 - acc: 0.8375 - val_loss: 0.9020 - val_acc: 0.6474
# Epoch 120/200
#  - 1s - loss: 0.4373 - acc: 0.8126 - val_loss: 0.9025 - val_acc: 0.6526
# Epoch 121/200
#  - 1s - loss: 0.3966 - acc: 0.8578 - val_loss: 0.9029 - val_acc: 0.6421
# Epoch 122/200
#  - 1s - loss: 0.4163 - acc: 0.8284 - val_loss: 0.9039 - val_acc: 0.6421
# Epoch 123/200
#  - 1s - loss: 0.4243 - acc: 0.8375 - val_loss: 0.9031 - val_acc: 0.6421
# Epoch 124/200
#  - 1s - loss: 0.3953 - acc: 0.8578 - val_loss: 0.9040 - val_acc: 0.6421
# Epoch 125/200
#  - 1s - loss: 0.4012 - acc: 0.8397 - val_loss: 0.9040 - val_acc: 0.6474
# Epoch 126/200
#  - 1s - loss: 0.3908 - acc: 0.8578 - val_loss: 0.9046 - val_acc: 0.6421
# Epoch 127/200
#  - 1s - loss: 0.4310 - acc: 0.8375 - val_loss: 0.9049 - val_acc: 0.6368
# Epoch 128/200
#  - 1s - loss: 0.3685 - acc: 0.8510 - val_loss: 0.9047 - val_acc: 0.6368
# Epoch 129/200
#  - 1s - loss: 0.3846 - acc: 0.8578 - val_loss: 0.9044 - val_acc: 0.6421
# Epoch 130/200
#  - 1s - loss: 0.4430 - acc: 0.8126 - val_loss: 0.9038 - val_acc: 0.6421

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
model.save('VGG-ish_73.model')
