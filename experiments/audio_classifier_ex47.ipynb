# %%
import os
from Audio_reader import readtf
from getman import getmanlist
import gc
import numpy as np
import pandas as pd
import pickle
from keras.layers import Dense, Input, Dropout,Flatten,MaxPooling1D,SpatialDropout2D
from keras.layers import Conv1D, MaxPooling2D,BatchNormalization,Conv2D
from keras.models import Model
from keras.models import Sequential
from keras import optimizers
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras import regularizers

# %%
def check(y):
    if 74 in y:
        return 0 
    #male
    if 1 in y:
        return 1
    #female
    if 2 in y:
        return 2
    #child
    if 3 in y:
        return 3
    return 0

# %%
X = []
Y = [] 
with open("X_list_eval.pickle","rb") as xf:
    X.extend(pickle.load(xf))
with open("Y_list_eval.pickle","rb") as xf:
    Y.extend(pickle.load(xf))
      
with open("X_list.pickle","rb") as xf:
    X.extend(pickle.load(xf))
with open("Y_list.pickle","rb") as xf:
    Y.extend(pickle.load(xf))

X=np.array(X)
Y=np.array(Y)  

X = X.astype('float32')    
X /= 128

# %%
learning_rate=0.001
#decay=0.000001
momentum=0.99
dropout_rate = 0.3

rglrzr = regularizers.l2(0.0015)

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same',activation='relu',input_shape=X.shape[1:]))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), padding='same',activation='relu',input_shape=X.shape[1:]))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(SpatialDropout2D(rate=dropout_rate))

model.add(Conv2D(128, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(SpatialDropout2D(rate=dropout_rate))



model.add(Conv2D(256, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(256, (1, 1), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(SpatialDropout2D(rate=dropout_rate))


model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (1, 1), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(SpatialDropout2D(rate=dropout_rate))



model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (1, 1), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(SpatialDropout2D(rate=dropout_rate))




model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_385 (Conv2D)          (None, 10, 128, 64)       640
# _________________________________________________________________
# batch_normalization_383 (Bat (None, 10, 128, 64)       256
# _________________________________________________________________
# conv2d_386 (Conv2D)          (None, 10, 128, 64)       36928
# _________________________________________________________________
# batch_normalization_384 (Bat (None, 10, 128, 64)       256
# _________________________________________________________________
# max_pooling2d_214 (MaxPoolin (None, 5, 64, 64)         0
# _________________________________________________________________
# spatial_dropout2d_56 (Spatia (None, 5, 64, 64)         0
# _________________________________________________________________
# conv2d_387 (Conv2D)          (None, 5, 64, 128)        73856
# _________________________________________________________________
# batch_normalization_385 (Bat (None, 5, 64, 128)        512
# _________________________________________________________________
# conv2d_388 (Conv2D)          (None, 5, 64, 128)        147584
# _________________________________________________________________
# batch_normalization_386 (Bat (None, 5, 64, 128)        512
# _________________________________________________________________
# max_pooling2d_215 (MaxPoolin (None, 5, 32, 128)        0
# _________________________________________________________________
# spatial_dropout2d_57 (Spatia (None, 5, 32, 128)        0
# _________________________________________________________________
# conv2d_389 (Conv2D)          (None, 5, 32, 256)        295168
# _________________________________________________________________
# batch_normalization_387 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# conv2d_390 (Conv2D)          (None, 5, 32, 256)        590080
# _________________________________________________________________
# batch_normalization_388 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# conv2d_391 (Conv2D)          (None, 5, 32, 256)        65792
# _________________________________________________________________
# batch_normalization_389 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# max_pooling2d_216 (MaxPoolin (None, 2, 16, 256)        0
# _________________________________________________________________
# spatial_dropout2d_58 (Spatia (None, 2, 16, 256)        0
# _________________________________________________________________
# conv2d_392 (Conv2D)          (None, 2, 16, 512)        1180160
# _________________________________________________________________
# batch_normalization_390 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# conv2d_393 (Conv2D)          (None, 2, 16, 512)        2359808
# _________________________________________________________________
# batch_normalization_391 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# conv2d_394 (Conv2D)          (None, 2, 16, 512)        262656
# _________________________________________________________________
# batch_normalization_392 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# max_pooling2d_217 (MaxPoolin (None, 2, 8, 512)         0
# _________________________________________________________________
# spatial_dropout2d_59 (Spatia (None, 2, 8, 512)         0
# _________________________________________________________________
# conv2d_395 (Conv2D)          (None, 2, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_393 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# conv2d_396 (Conv2D)          (None, 2, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_394 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# conv2d_397 (Conv2D)          (None, 2, 8, 512)         262656
# _________________________________________________________________
# batch_normalization_395 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# max_pooling2d_218 (MaxPoolin (None, 2, 4, 512)         0
# _________________________________________________________________
# spatial_dropout2d_60 (Spatia (None, 2, 4, 512)         0
# _________________________________________________________________
# flatten_55 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_110 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_111 (Dense)            (None, 3)                 387
# =================================================================
# Total params: 10,536,643
# Trainable params: 10,528,195
# Non-trainable params: 8,448
# _________________________________________________________________

# %%
optimizer = optimizers.SGD(lr=learning_rate,momentum=momentum)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer, 
              metrics=['accuracy'])

# %%
cb=[]

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.75, patience=4, verbose=0, mode='auto')
early_stopping = EarlyStopping(monitor='acc', min_delta=0, patience=30, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

cb.append(reduce_lr)
cb.append(early_stopping)

# %%
history=model.fit(X, Y,
          batch_size=32,
          epochs=200,
          verbose=2,
          callbacks=cb,
          validation_split=0.2,
          shuffle=True)
# Out:
# Train on 506 samples, validate on 127 samples
# Epoch 1/200
#  - 25s - loss: 0.9374 - acc: 0.6126 - val_loss: 1.0599 - val_acc: 0.5197
# Epoch 2/200
#  - 2s - loss: 0.9224 - acc: 0.6186 - val_loss: 1.0560 - val_acc: 0.5197
# Epoch 3/200
#  - 2s - loss: 0.9155 - acc: 0.6166 - val_loss: 1.0309 - val_acc: 0.5354
# Epoch 4/200
#  - 2s - loss: 0.8970 - acc: 0.6304 - val_loss: 1.0261 - val_acc: 0.5433
# Epoch 5/200
#  - 2s - loss: 0.9018 - acc: 0.6107 - val_loss: 1.0248 - val_acc: 0.5118
# Epoch 6/200
#  - 2s - loss: 0.8824 - acc: 0.6166 - val_loss: 0.9840 - val_acc: 0.5512
# Epoch 7/200
#  - 2s - loss: 0.8676 - acc: 0.6423 - val_loss: 0.9695 - val_acc: 0.5906
# Epoch 8/200
#  - 2s - loss: 0.8906 - acc: 0.6126 - val_loss: 0.9642 - val_acc: 0.5827
# Epoch 9/200
#  - 2s - loss: 0.8570 - acc: 0.6423 - val_loss: 0.9871 - val_acc: 0.5276
# Epoch 10/200
#  - 2s - loss: 0.8433 - acc: 0.6206 - val_loss: 0.9909 - val_acc: 0.5276
# Epoch 11/200
#  - 2s - loss: 0.8568 - acc: 0.6344 - val_loss: 1.0716 - val_acc: 0.5512
# Epoch 12/200
#  - 2s - loss: 0.8458 - acc: 0.6166 - val_loss: 1.1314 - val_acc: 0.5197
# Epoch 13/200
#  - 2s - loss: 0.8140 - acc: 0.6443 - val_loss: 1.1406 - val_acc: 0.5512
# Epoch 14/200
#  - 2s - loss: 0.8526 - acc: 0.6364 - val_loss: 1.0982 - val_acc: 0.5984
# Epoch 15/200
#  - 2s - loss: 0.8285 - acc: 0.6403 - val_loss: 1.0457 - val_acc: 0.5827
# Epoch 16/200
#  - 2s - loss: 0.8269 - acc: 0.6067 - val_loss: 1.0203 - val_acc: 0.5827
# Epoch 17/200
#  - 2s - loss: 0.7846 - acc: 0.6561 - val_loss: 1.0452 - val_acc: 0.5827
# Epoch 18/200
#  - 2s - loss: 0.7991 - acc: 0.6344 - val_loss: 1.0126 - val_acc: 0.5748
# Epoch 19/200
#  - 2s - loss: 0.7892 - acc: 0.6146 - val_loss: 1.0160 - val_acc: 0.5984
# Epoch 20/200
#  - 2s - loss: 0.7750 - acc: 0.6542 - val_loss: 1.0382 - val_acc: 0.5906
# Epoch 21/200
#  - 2s - loss: 0.8035 - acc: 0.6304 - val_loss: 1.0024 - val_acc: 0.5591
# Epoch 22/200
#  - 2s - loss: 0.7733 - acc: 0.6383 - val_loss: 0.9417 - val_acc: 0.5906
# Epoch 23/200
#  - 2s - loss: 0.7709 - acc: 0.6581 - val_loss: 0.9187 - val_acc: 0.5906
# Epoch 24/200
#  - 2s - loss: 0.7646 - acc: 0.6324 - val_loss: 0.9111 - val_acc: 0.5984
# Epoch 25/200
#  - 2s - loss: 0.7560 - acc: 0.6561 - val_loss: 0.9571 - val_acc: 0.5984
# Epoch 26/200
#  - 2s - loss: 0.7622 - acc: 0.6621 - val_loss: 0.9529 - val_acc: 0.5591
# Epoch 27/200
#  - 2s - loss: 0.7317 - acc: 0.6542 - val_loss: 0.9975 - val_acc: 0.5827
# Epoch 28/200
#  - 2s - loss: 0.7349 - acc: 0.6621 - val_loss: 1.0085 - val_acc: 0.5827
# Epoch 29/200
#  - 2s - loss: 0.7285 - acc: 0.6838 - val_loss: 0.9378 - val_acc: 0.5906
# Epoch 30/200
#  - 2s - loss: 0.7239 - acc: 0.6838 - val_loss: 0.8909 - val_acc: 0.6063
# Epoch 31/200
#  - 2s - loss: 0.7141 - acc: 0.6719 - val_loss: 0.8839 - val_acc: 0.6063
# Epoch 32/200
#  - 2s - loss: 0.6953 - acc: 0.6818 - val_loss: 0.8754 - val_acc: 0.6535
# Epoch 33/200
#  - 2s - loss: 0.6890 - acc: 0.6621 - val_loss: 0.9271 - val_acc: 0.5669
# Epoch 34/200
#  - 2s - loss: 0.6775 - acc: 0.6759 - val_loss: 0.9964 - val_acc: 0.5669
# Epoch 35/200
#  - 2s - loss: 0.6868 - acc: 0.6937 - val_loss: 1.0197 - val_acc: 0.6142
# Epoch 36/200
#  - 2s - loss: 0.6865 - acc: 0.6897 - val_loss: 0.9064 - val_acc: 0.5669
# Epoch 37/200
#  - 2s - loss: 0.7106 - acc: 0.6759 - val_loss: 0.9120 - val_acc: 0.6063
# Epoch 38/200
#  - 2s - loss: 0.7082 - acc: 0.6759 - val_loss: 0.9739 - val_acc: 0.6063
# Epoch 39/200
#  - 2s - loss: 0.6378 - acc: 0.7016 - val_loss: 0.9428 - val_acc: 0.6063
# Epoch 40/200
#  - 2s - loss: 0.6390 - acc: 0.6897 - val_loss: 0.9382 - val_acc: 0.6220
# Epoch 41/200
#  - 2s - loss: 0.6419 - acc: 0.6976 - val_loss: 0.9847 - val_acc: 0.6378
# Epoch 42/200
#  - 2s - loss: 0.6817 - acc: 0.6996 - val_loss: 0.9711 - val_acc: 0.5984
# Epoch 43/200
#  - 2s - loss: 0.6312 - acc: 0.7055 - val_loss: 0.9589 - val_acc: 0.6220
# Epoch 44/200
#  - 2s - loss: 0.5990 - acc: 0.7154 - val_loss: 0.9365 - val_acc: 0.5906
# Epoch 45/200
#  - 2s - loss: 0.6554 - acc: 0.6798 - val_loss: 0.9282 - val_acc: 0.6220
# Epoch 46/200
#  - 2s - loss: 0.6235 - acc: 0.7115 - val_loss: 0.9545 - val_acc: 0.6220
# Epoch 47/200
#  - 2s - loss: 0.6231 - acc: 0.7036 - val_loss: 0.9968 - val_acc: 0.5984
# Epoch 48/200
#  - 2s - loss: 0.6295 - acc: 0.6996 - val_loss: 1.0414 - val_acc: 0.5984
# Epoch 49/200
#  - 2s - loss: 0.6020 - acc: 0.7233 - val_loss: 1.0508 - val_acc: 0.6142
# Epoch 50/200
#  - 2s - loss: 0.6226 - acc: 0.7134 - val_loss: 1.0260 - val_acc: 0.5906
# Epoch 51/200
#  - 2s - loss: 0.6034 - acc: 0.7075 - val_loss: 0.9949 - val_acc: 0.6063
# Epoch 52/200
#  - 2s - loss: 0.6373 - acc: 0.7273 - val_loss: 1.0261 - val_acc: 0.6299
# Epoch 53/200
#  - 2s - loss: 0.5996 - acc: 0.7253 - val_loss: 1.0215 - val_acc: 0.5827
# Epoch 54/200
#  - 2s - loss: 0.5877 - acc: 0.7154 - val_loss: 1.0304 - val_acc: 0.6063
# Epoch 55/200
#  - 2s - loss: 0.5973 - acc: 0.7253 - val_loss: 1.0501 - val_acc: 0.6142
# Epoch 56/200
#  - 2s - loss: 0.5783 - acc: 0.7233 - val_loss: 1.0246 - val_acc: 0.5827
# Epoch 57/200
#  - 2s - loss: 0.5873 - acc: 0.7036 - val_loss: 1.0336 - val_acc: 0.6378
# Epoch 58/200
#  - 2s - loss: 0.6071 - acc: 0.7095 - val_loss: 1.0744 - val_acc: 0.5906
# Epoch 59/200
#  - 2s - loss: 0.5707 - acc: 0.7233 - val_loss: 1.0629 - val_acc: 0.5906
# Epoch 60/200
#  - 2s - loss: 0.5703 - acc: 0.7095 - val_loss: 1.0455 - val_acc: 0.5984
# Epoch 61/200
#  - 2s - loss: 0.5528 - acc: 0.7352 - val_loss: 1.0583 - val_acc: 0.5827
# Epoch 62/200
#  - 2s - loss: 0.5939 - acc: 0.7055 - val_loss: 1.0695 - val_acc: 0.5512
# Epoch 63/200
#  - 2s - loss: 0.5873 - acc: 0.7016 - val_loss: 1.0213 - val_acc: 0.5984
# Epoch 64/200
#  - 2s - loss: 0.5279 - acc: 0.7530 - val_loss: 1.0141 - val_acc: 0.5984
# Epoch 65/200
#  - 2s - loss: 0.5148 - acc: 0.7510 - val_loss: 1.0577 - val_acc: 0.5669
# Epoch 66/200
#  - 2s - loss: 0.5586 - acc: 0.7253 - val_loss: 1.0801 - val_acc: 0.5984
# Epoch 67/200
#  - 2s - loss: 0.5131 - acc: 0.7490 - val_loss: 1.0924 - val_acc: 0.5984
# Epoch 68/200
#  - 2s - loss: 0.5372 - acc: 0.7372 - val_loss: 1.1309 - val_acc: 0.5827
# Epoch 69/200
#  - 2s - loss: 0.5331 - acc: 0.7411 - val_loss: 1.1136 - val_acc: 0.5827
# Epoch 70/200
#  - 2s - loss: 0.5366 - acc: 0.7451 - val_loss: 1.0819 - val_acc: 0.5906
# Epoch 71/200
#  - 2s - loss: 0.5491 - acc: 0.7213 - val_loss: 1.0554 - val_acc: 0.5748
# Epoch 72/200
#  - 2s - loss: 0.5047 - acc: 0.7549 - val_loss: 1.0193 - val_acc: 0.5827
# Epoch 73/200
#  - 2s - loss: 0.5029 - acc: 0.7589 - val_loss: 1.0167 - val_acc: 0.5827
# Epoch 74/200
#  - 2s - loss: 0.5168 - acc: 0.7510 - val_loss: 1.0540 - val_acc: 0.5984
# Epoch 75/200
#  - 2s - loss: 0.4901 - acc: 0.7549 - val_loss: 1.0713 - val_acc: 0.5906
# Epoch 76/200
#  - 2s - loss: 0.5081 - acc: 0.7490 - val_loss: 1.0725 - val_acc: 0.5748
# Epoch 77/200
#  - 2s - loss: 0.4887 - acc: 0.7411 - val_loss: 1.0800 - val_acc: 0.5906
# Epoch 78/200
#  - 2s - loss: 0.5068 - acc: 0.7431 - val_loss: 1.0879 - val_acc: 0.5984
# Epoch 79/200
#  - 2s - loss: 0.5027 - acc: 0.7628 - val_loss: 1.0874 - val_acc: 0.5984
# Epoch 80/200
#  - 2s - loss: 0.4859 - acc: 0.7292 - val_loss: 1.1175 - val_acc: 0.5433
# Epoch 81/200
#  - 2s - loss: 0.5105 - acc: 0.7391 - val_loss: 1.1129 - val_acc: 0.5984
# Epoch 82/200
#  - 2s - loss: 0.5112 - acc: 0.7411 - val_loss: 1.1197 - val_acc: 0.5906
# Epoch 83/200
#  - 2s - loss: 0.5113 - acc: 0.7609 - val_loss: 1.1382 - val_acc: 0.6142
# Epoch 84/200
#  - 2s - loss: 0.4926 - acc: 0.7609 - val_loss: 1.1079 - val_acc: 0.5984
# Epoch 85/200
#  - 2s - loss: 0.4960 - acc: 0.7648 - val_loss: 1.0821 - val_acc: 0.5984
# Epoch 86/200
#  - 2s - loss: 0.4610 - acc: 0.7510 - val_loss: 1.0679 - val_acc: 0.5827
# Epoch 87/200
#  - 2s - loss: 0.4846 - acc: 0.7510 - val_loss: 1.0553 - val_acc: 0.6063
# Epoch 88/200
#  - 2s - loss: 0.4897 - acc: 0.7530 - val_loss: 1.0714 - val_acc: 0.6220
# Epoch 89/200
#  - 2s - loss: 0.4747 - acc: 0.7609 - val_loss: 1.0935 - val_acc: 0.5827
# Epoch 90/200
#  - 2s - loss: 0.4477 - acc: 0.7787 - val_loss: 1.1331 - val_acc: 0.5827
# Epoch 91/200
#  - 2s - loss: 0.4731 - acc: 0.7708 - val_loss: 1.1848 - val_acc: 0.6378
# Epoch 92/200
#  - 2s - loss: 0.4641 - acc: 0.7589 - val_loss: 1.2297 - val_acc: 0.5984
# Epoch 93/200
#  - 2s - loss: 0.4713 - acc: 0.7530 - val_loss: 1.2443 - val_acc: 0.5827
# Epoch 94/200
#  - 2s - loss: 0.4969 - acc: 0.7727 - val_loss: 1.2326 - val_acc: 0.6063
# Epoch 95/200
#  - 2s - loss: 0.5044 - acc: 0.7530 - val_loss: 1.1958 - val_acc: 0.5748
# Epoch 96/200
#  - 2s - loss: 0.4670 - acc: 0.7668 - val_loss: 1.1568 - val_acc: 0.5748
# Epoch 97/200
#  - 2s - loss: 0.4540 - acc: 0.7648 - val_loss: 1.1218 - val_acc: 0.5984
# Epoch 98/200
#  - 2s - loss: 0.4842 - acc: 0.7589 - val_loss: 1.1155 - val_acc: 0.6299
# Epoch 99/200
#  - 2s - loss: 0.4796 - acc: 0.7549 - val_loss: 1.1205 - val_acc: 0.6063
# Epoch 100/200
#  - 2s - loss: 0.4477 - acc: 0.7490 - val_loss: 1.1273 - val_acc: 0.5748
# Epoch 101/200
#  - 2s - loss: 0.4599 - acc: 0.7668 - val_loss: 1.1045 - val_acc: 0.6220
# Epoch 102/200
#  - 2s - loss: 0.4890 - acc: 0.7628 - val_loss: 1.1121 - val_acc: 0.5984
# Epoch 103/200
#  - 2s - loss: 0.4483 - acc: 0.7727 - val_loss: 1.1100 - val_acc: 0.5827
# Epoch 104/200
#  - 2s - loss: 0.4479 - acc: 0.7648 - val_loss: 1.1366 - val_acc: 0.5669
# Epoch 105/200
#  - 2s - loss: 0.4596 - acc: 0.7510 - val_loss: 1.1602 - val_acc: 0.5906
# Epoch 106/200
#  - 2s - loss: 0.4385 - acc: 0.7747 - val_loss: 1.1764 - val_acc: 0.6063
# Epoch 107/200
#  - 2s - loss: 0.4822 - acc: 0.7569 - val_loss: 1.1936 - val_acc: 0.6063
# Epoch 108/200
#  - 2s - loss: 0.4943 - acc: 0.7490 - val_loss: 1.1828 - val_acc: 0.5984
# Epoch 109/200
#  - 2s - loss: 0.4605 - acc: 0.7668 - val_loss: 1.1820 - val_acc: 0.5748
# Epoch 110/200
#  - 2s - loss: 0.4617 - acc: 0.7787 - val_loss: 1.1725 - val_acc: 0.5591
# Epoch 111/200
#  - 2s - loss: 0.4377 - acc: 0.7945 - val_loss: 1.1626 - val_acc: 0.5827
# Epoch 112/200
#  - 2s - loss: 0.4292 - acc: 0.7708 - val_loss: 1.1610 - val_acc: 0.5906
# Epoch 113/200
#  - 2s - loss: 0.4389 - acc: 0.7767 - val_loss: 1.1530 - val_acc: 0.5984
# Epoch 114/200
#  - 2s - loss: 0.4390 - acc: 0.7688 - val_loss: 1.1564 - val_acc: 0.5748
# Epoch 115/200
#  - 2s - loss: 0.4255 - acc: 0.7826 - val_loss: 1.1587 - val_acc: 0.5512
# Epoch 116/200
#  - 2s - loss: 0.4403 - acc: 0.7688 - val_loss: 1.1509 - val_acc: 0.5827
# Epoch 117/200
#  - 2s - loss: 0.4456 - acc: 0.7609 - val_loss: 1.1438 - val_acc: 0.5906
# Epoch 118/200
#  - 2s - loss: 0.4274 - acc: 0.7648 - val_loss: 1.1448 - val_acc: 0.6142
# Epoch 119/200
#  - 2s - loss: 0.4292 - acc: 0.7806 - val_loss: 1.1417 - val_acc: 0.5906
# Epoch 120/200
#  - 2s - loss: 0.4075 - acc: 0.7885 - val_loss: 1.1443 - val_acc: 0.5669
# Epoch 121/200
#  - 2s - loss: 0.4392 - acc: 0.7905 - val_loss: 1.1488 - val_acc: 0.5748
# Epoch 122/200
#  - 2s - loss: 0.4136 - acc: 0.7806 - val_loss: 1.1517 - val_acc: 0.5669
# Epoch 123/200
#  - 2s - loss: 0.4211 - acc: 0.7826 - val_loss: 1.1616 - val_acc: 0.5906
# Epoch 124/200
#  - 2s - loss: 0.4581 - acc: 0.7609 - val_loss: 1.1713 - val_acc: 0.5906
# Epoch 125/200
#  - 2s - loss: 0.4171 - acc: 0.7846 - val_loss: 1.1805 - val_acc: 0.5906
# Epoch 126/200
#  - 2s - loss: 0.4211 - acc: 0.7925 - val_loss: 1.1911 - val_acc: 0.5906
# Epoch 127/200
#  - 2s - loss: 0.4243 - acc: 0.7688 - val_loss: 1.2012 - val_acc: 0.5748
# Epoch 128/200
#  - 2s - loss: 0.4204 - acc: 0.7925 - val_loss: 1.2125 - val_acc: 0.5748
# Epoch 129/200
#  - 2s - loss: 0.4243 - acc: 0.7787 - val_loss: 1.2171 - val_acc: 0.5906
# Epoch 130/200
#  - 2s - loss: 0.4639 - acc: 0.7668 - val_loss: 1.2228 - val_acc: 0.6063
# Epoch 131/200
#  - 2s - loss: 0.4021 - acc: 0.7846 - val_loss: 1.2235 - val_acc: 0.6142
# Epoch 132/200
#  - 2s - loss: 0.4410 - acc: 0.7747 - val_loss: 1.2258 - val_acc: 0.6142
# Epoch 133/200
#  - 2s - loss: 0.4085 - acc: 0.7767 - val_loss: 1.2254 - val_acc: 0.6063
# Epoch 134/200
#  - 2s - loss: 0.4554 - acc: 0.7589 - val_loss: 1.2270 - val_acc: 0.6063
# Epoch 135/200
#  - 2s - loss: 0.4528 - acc: 0.7648 - val_loss: 1.2220 - val_acc: 0.5984
# Epoch 136/200
#  - 2s - loss: 0.4107 - acc: 0.7510 - val_loss: 1.2181 - val_acc: 0.5827
# Epoch 137/200
#  - 2s - loss: 0.4240 - acc: 0.7668 - val_loss: 1.2162 - val_acc: 0.5748
# Epoch 138/200
#  - 2s - loss: 0.4459 - acc: 0.7846 - val_loss: 1.2137 - val_acc: 0.5748
# Epoch 139/200
#  - 2s - loss: 0.4251 - acc: 0.7609 - val_loss: 1.2115 - val_acc: 0.5748
# Epoch 140/200
#  - 2s - loss: 0.4102 - acc: 0.7609 - val_loss: 1.2101 - val_acc: 0.5827
# Epoch 141/200
#  - 2s - loss: 0.4332 - acc: 0.7846 - val_loss: 1.2098 - val_acc: 0.5906

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
model.save('VGG-ish_73.model')
