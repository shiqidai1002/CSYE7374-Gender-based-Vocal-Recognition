# %%
import os
from Audio_reader import readtf
from getman import getmanlist
import gc
import numpy as np
import pandas as pd
import pickle
from keras.layers import Dense, Input, Dropout,Flatten,MaxPooling1D
from keras.layers import Conv1D, MaxPooling2D,BatchNormalization,Conv2D
from keras.models import Model
from keras.models import Sequential
from keras import optimizers
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras import regularizers

# %%
def check(y):
    if 74 in y:
        return 0 
    #male
    if 1 in y:
        return 1
    #female
    if 2 in y:
        return 2
    #child
    if 3 in y:
        return 3
    return 0

# %%
X = []
Y = [] 
with open("X_list_eval.pickle","rb") as xf:
    X.extend(pickle.load(xf))
with open("Y_list_eval.pickle","rb") as xf:
    Y.extend(pickle.load(xf))
      
with open("X_list.pickle","rb") as xf:
    X.extend(pickle.load(xf))
with open("Y_list.pickle","rb") as xf:
    Y.extend(pickle.load(xf))

X=np.array(X)
Y=np.array(Y)  

X = X.astype('float32')    
X /= 128

# %%
learning_rate=0.0003
#decay=0.000001
momentum=0.99
dropout_rate = 0.25

rglrzr = regularizers.l2(0.0012)

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same',activation='relu',input_shape=X.shape[1:]))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=dropout_rate))

model.add(Conv2D(128, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(Dropout(rate=dropout_rate))



model.add(Conv2D(256, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=dropout_rate))


model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(Dropout(rate=dropout_rate))



model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(Dropout(rate=dropout_rate))




model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(3,activation='softmax'))
model.summary()

optimizer = optimizers.SGD(lr=learning_rate,momentum=momentum)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer, 
              metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_256 (Conv2D)          (None, 10, 128, 64)       640
# _________________________________________________________________
# batch_normalization_254 (Bat (None, 10, 128, 64)       256
# _________________________________________________________________
# max_pooling2d_133 (MaxPoolin (None, 5, 64, 64)         0
# _________________________________________________________________
# dropout_136 (Dropout)        (None, 5, 64, 64)         0
# _________________________________________________________________
# conv2d_257 (Conv2D)          (None, 5, 64, 128)        73856
# _________________________________________________________________
# batch_normalization_255 (Bat (None, 5, 64, 128)        512
# _________________________________________________________________
# max_pooling2d_134 (MaxPoolin (None, 5, 32, 128)        0
# _________________________________________________________________
# dropout_137 (Dropout)        (None, 5, 32, 128)        0
# _________________________________________________________________
# conv2d_258 (Conv2D)          (None, 5, 32, 256)        295168
# _________________________________________________________________
# batch_normalization_256 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# conv2d_259 (Conv2D)          (None, 5, 32, 256)        590080
# _________________________________________________________________
# batch_normalization_257 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# max_pooling2d_135 (MaxPoolin (None, 2, 16, 256)        0
# _________________________________________________________________
# dropout_138 (Dropout)        (None, 2, 16, 256)        0
# _________________________________________________________________
# conv2d_260 (Conv2D)          (None, 2, 16, 512)        1180160
# _________________________________________________________________
# batch_normalization_258 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# conv2d_261 (Conv2D)          (None, 2, 16, 512)        2359808
# _________________________________________________________________
# batch_normalization_259 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# max_pooling2d_136 (MaxPoolin (None, 2, 8, 512)         0
# _________________________________________________________________
# dropout_139 (Dropout)        (None, 2, 8, 512)         0
# _________________________________________________________________
# conv2d_262 (Conv2D)          (None, 2, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_260 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# conv2d_263 (Conv2D)          (None, 2, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_261 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# max_pooling2d_137 (MaxPoolin (None, 2, 4, 512)         0
# _________________________________________________________________
# dropout_140 (Dropout)        (None, 2, 4, 512)         0
# _________________________________________________________________
# flatten_39 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_78 (Dense)             (None, 128)               524416
# _________________________________________________________________
# dense_79 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 9,755,139
# Trainable params: 9,749,635
# Non-trainable params: 5,504
# _________________________________________________________________

# %%
cb=[]

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=3, verbose=0, mode='auto')
early_stopping = EarlyStopping(monitor='acc', min_delta=0, patience=30, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

cb.append(reduce_lr)
cb.append(early_stopping)

# %%
history=model.fit(X, Y,
          batch_size=32,
          epochs=200,
          verbose=2,
          callbacks=cb,
          validation_split=0.3,
          shuffle=True)
# Out:
# Train on 443 samples, validate on 190 samples
# Epoch 1/200
#  - 14s - loss: 1.6129 - acc: 0.4447 - val_loss: 1.6085 - val_acc: 0.3053
# Epoch 2/200
#  - 1s - loss: 1.2444 - acc: 0.5034 - val_loss: 1.1043 - val_acc: 0.4842
# Epoch 3/200
#  - 1s - loss: 1.1289 - acc: 0.5756 - val_loss: 1.0023 - val_acc: 0.5000
# Epoch 4/200
#  - 1s - loss: 1.0006 - acc: 0.5034 - val_loss: 1.9816 - val_acc: 0.5789
# Epoch 5/200
#  - 1s - loss: 0.9366 - acc: 0.5937 - val_loss: 2.7979 - val_acc: 0.5789
# Epoch 6/200
#  - 1s - loss: 0.8975 - acc: 0.6050 - val_loss: 1.9575 - val_acc: 0.5632
# Epoch 7/200
#  - 1s - loss: 0.8843 - acc: 0.6208 - val_loss: 1.7297 - val_acc: 0.5737
# Epoch 8/200
#  - 1s - loss: 0.8723 - acc: 0.6005 - val_loss: 1.7139 - val_acc: 0.5789
# Epoch 9/200
#  - 1s - loss: 0.8889 - acc: 0.6050 - val_loss: 1.0568 - val_acc: 0.5789
# Epoch 10/200
#  - 1s - loss: 0.8336 - acc: 0.6343 - val_loss: 1.0004 - val_acc: 0.5789
# Epoch 11/200
#  - 1s - loss: 0.7949 - acc: 0.6433 - val_loss: 1.0521 - val_acc: 0.5789
# Epoch 12/200
#  - 1s - loss: 0.7668 - acc: 0.6727 - val_loss: 1.0747 - val_acc: 0.5842
# Epoch 13/200
#  - 1s - loss: 0.7541 - acc: 0.6614 - val_loss: 1.0831 - val_acc: 0.5579
# Epoch 14/200
#  - 1s - loss: 0.7357 - acc: 0.6569 - val_loss: 1.0974 - val_acc: 0.5789
# Epoch 15/200
#  - 1s - loss: 0.6966 - acc: 0.6907 - val_loss: 0.9932 - val_acc: 0.5526
# Epoch 16/200
#  - 1s - loss: 0.6584 - acc: 0.7178 - val_loss: 0.9975 - val_acc: 0.5526
# Epoch 17/200
#  - 1s - loss: 0.6633 - acc: 0.7020 - val_loss: 0.9653 - val_acc: 0.5632
# Epoch 18/200
#  - 1s - loss: 0.6273 - acc: 0.7314 - val_loss: 0.9897 - val_acc: 0.5842
# Epoch 19/200
#  - 1s - loss: 0.6195 - acc: 0.7291 - val_loss: 0.9091 - val_acc: 0.6000
# Epoch 20/200
#  - 1s - loss: 0.5678 - acc: 0.7585 - val_loss: 0.8528 - val_acc: 0.6158
# Epoch 21/200
#  - 1s - loss: 0.5210 - acc: 0.7923 - val_loss: 0.8427 - val_acc: 0.6105
# Epoch 22/200
#  - 1s - loss: 0.5169 - acc: 0.7968 - val_loss: 0.9038 - val_acc: 0.6211
# Epoch 23/200
#  - 1s - loss: 0.4850 - acc: 0.7968 - val_loss: 0.9593 - val_acc: 0.6211
# Epoch 24/200
#  - 1s - loss: 0.4456 - acc: 0.8194 - val_loss: 0.9716 - val_acc: 0.6105
# Epoch 25/200
#  - 1s - loss: 0.4461 - acc: 0.8172 - val_loss: 0.9830 - val_acc: 0.6211
# Epoch 26/200
#  - 1s - loss: 0.3964 - acc: 0.8284 - val_loss: 0.9598 - val_acc: 0.6105
# Epoch 27/200
#  - 1s - loss: 0.3673 - acc: 0.8758 - val_loss: 0.9699 - val_acc: 0.6000
# Epoch 28/200
#  - 1s - loss: 0.3545 - acc: 0.8555 - val_loss: 0.9816 - val_acc: 0.6158
# Epoch 29/200
#  - 1s - loss: 0.3090 - acc: 0.8713 - val_loss: 1.0131 - val_acc: 0.6053
# Epoch 30/200
#  - 1s - loss: 0.3365 - acc: 0.8668 - val_loss: 1.0366 - val_acc: 0.6105
# Epoch 31/200
#  - 1s - loss: 0.3017 - acc: 0.8826 - val_loss: 1.0953 - val_acc: 0.6000
# Epoch 32/200
#  - 1s - loss: 0.2526 - acc: 0.9007 - val_loss: 1.1285 - val_acc: 0.5947
# Epoch 33/200
#  - 1s - loss: 0.2532 - acc: 0.9052 - val_loss: 1.1296 - val_acc: 0.6211
# Epoch 34/200
#  - 1s - loss: 0.2258 - acc: 0.9165 - val_loss: 1.1044 - val_acc: 0.6368
# Epoch 35/200
#  - 1s - loss: 0.2058 - acc: 0.9278 - val_loss: 1.0888 - val_acc: 0.6474
# Epoch 36/200
#  - 1s - loss: 0.1872 - acc: 0.9323 - val_loss: 1.0859 - val_acc: 0.6684
# Epoch 37/200
#  - 1s - loss: 0.1912 - acc: 0.9345 - val_loss: 1.0896 - val_acc: 0.6842
# Epoch 38/200
#  - 1s - loss: 0.1598 - acc: 0.9458 - val_loss: 1.0997 - val_acc: 0.7000
# Epoch 39/200
#  - 1s - loss: 0.1814 - acc: 0.9300 - val_loss: 1.1113 - val_acc: 0.6895
# Epoch 40/200
#  - 1s - loss: 0.1649 - acc: 0.9481 - val_loss: 1.1170 - val_acc: 0.6895
# Epoch 41/200
#  - 1s - loss: 0.1486 - acc: 0.9571 - val_loss: 1.1411 - val_acc: 0.6842
# Epoch 42/200
#  - 1s - loss: 0.1534 - acc: 0.9391 - val_loss: 1.1797 - val_acc: 0.6684
# Epoch 43/200
#  - 1s - loss: 0.1185 - acc: 0.9616 - val_loss: 1.2224 - val_acc: 0.6684
# Epoch 44/200
#  - 1s - loss: 0.1519 - acc: 0.9436 - val_loss: 1.2578 - val_acc: 0.6737
# Epoch 45/200
#  - 1s - loss: 0.1234 - acc: 0.9594 - val_loss: 1.3038 - val_acc: 0.6789
# Epoch 46/200
#  - 1s - loss: 0.1184 - acc: 0.9413 - val_loss: 1.3628 - val_acc: 0.6632
# Epoch 47/200
#  - 1s - loss: 0.1262 - acc: 0.9503 - val_loss: 1.4252 - val_acc: 0.6579
# Epoch 48/200
#  - 1s - loss: 0.1121 - acc: 0.9503 - val_loss: 1.4769 - val_acc: 0.6263
# Epoch 49/200
#  - 1s - loss: 0.1155 - acc: 0.9639 - val_loss: 1.5043 - val_acc: 0.6158
# Epoch 50/200
#  - 1s - loss: 0.1173 - acc: 0.9571 - val_loss: 1.4699 - val_acc: 0.6421
# Epoch 51/200
#  - 1s - loss: 0.0799 - acc: 0.9819 - val_loss: 1.4156 - val_acc: 0.6474
# Epoch 52/200
#  - 1s - loss: 0.0925 - acc: 0.9639 - val_loss: 1.3735 - val_acc: 0.6684
# Epoch 53/200
#  - 1s - loss: 0.0791 - acc: 0.9729 - val_loss: 1.3491 - val_acc: 0.7000
# Epoch 54/200
#  - 1s - loss: 0.1026 - acc: 0.9707 - val_loss: 1.3445 - val_acc: 0.7000
# Epoch 55/200
#  - 1s - loss: 0.0762 - acc: 0.9729 - val_loss: 1.3500 - val_acc: 0.7053
# Epoch 56/200
#  - 1s - loss: 0.1017 - acc: 0.9661 - val_loss: 1.3574 - val_acc: 0.7000
# Epoch 57/200
#  - 1s - loss: 0.0662 - acc: 0.9707 - val_loss: 1.3592 - val_acc: 0.7000
# Epoch 58/200
#  - 1s - loss: 0.0924 - acc: 0.9639 - val_loss: 1.3650 - val_acc: 0.6947
# Epoch 59/200
#  - 1s - loss: 0.0891 - acc: 0.9684 - val_loss: 1.3751 - val_acc: 0.6842
# Epoch 60/200
#  - 1s - loss: 0.0786 - acc: 0.9774 - val_loss: 1.3903 - val_acc: 0.6526
# Epoch 61/200
#  - 1s - loss: 0.1127 - acc: 0.9571 - val_loss: 1.4075 - val_acc: 0.6474
# Epoch 62/200
#  - 1s - loss: 0.0738 - acc: 0.9752 - val_loss: 1.4212 - val_acc: 0.6474
# Epoch 63/200
#  - 1s - loss: 0.0637 - acc: 0.9729 - val_loss: 1.4284 - val_acc: 0.6474
# Epoch 64/200
#  - 1s - loss: 0.0703 - acc: 0.9774 - val_loss: 1.4312 - val_acc: 0.6474
# Epoch 65/200
#  - 1s - loss: 0.0568 - acc: 0.9842 - val_loss: 1.4348 - val_acc: 0.6474
# Epoch 66/200
#  - 1s - loss: 0.0608 - acc: 0.9887 - val_loss: 1.4375 - val_acc: 0.6579
# Epoch 67/200
#  - 1s - loss: 0.0662 - acc: 0.9774 - val_loss: 1.4413 - val_acc: 0.6579
# Epoch 68/200
#  - 1s - loss: 0.0535 - acc: 0.9819 - val_loss: 1.4448 - val_acc: 0.6632
# Epoch 69/200
#  - 1s - loss: 0.0866 - acc: 0.9729 - val_loss: 1.4448 - val_acc: 0.6684
# Epoch 70/200
#  - 1s - loss: 0.0820 - acc: 0.9752 - val_loss: 1.4448 - val_acc: 0.6737
# Epoch 71/200
#  - 1s - loss: 0.0849 - acc: 0.9752 - val_loss: 1.4433 - val_acc: 0.6737
# Epoch 72/200
#  - 1s - loss: 0.0752 - acc: 0.9752 - val_loss: 1.4426 - val_acc: 0.6737
# Epoch 73/200
#  - 1s - loss: 0.0755 - acc: 0.9752 - val_loss: 1.4409 - val_acc: 0.6737
# Epoch 74/200
#  - 1s - loss: 0.0761 - acc: 0.9707 - val_loss: 1.4405 - val_acc: 0.6737
# Epoch 75/200
#  - 1s - loss: 0.0564 - acc: 0.9842 - val_loss: 1.4390 - val_acc: 0.6737
# Epoch 76/200
#  - 1s - loss: 0.0607 - acc: 0.9865 - val_loss: 1.4376 - val_acc: 0.6737
# Epoch 77/200
#  - 1s - loss: 0.0763 - acc: 0.9797 - val_loss: 1.4371 - val_acc: 0.6737
# Epoch 78/200
#  - 1s - loss: 0.0712 - acc: 0.9661 - val_loss: 1.4370 - val_acc: 0.6737
# Epoch 79/200
#  - 1s - loss: 0.0707 - acc: 0.9797 - val_loss: 1.4372 - val_acc: 0.6737
# Epoch 80/200
#  - 1s - loss: 0.0580 - acc: 0.9865 - val_loss: 1.4372 - val_acc: 0.6737
# Epoch 81/200
#  - 1s - loss: 0.0588 - acc: 0.9797 - val_loss: 1.4371 - val_acc: 0.6737
# Epoch 82/200
#  - 1s - loss: 0.0528 - acc: 0.9797 - val_loss: 1.4364 - val_acc: 0.6737
# Epoch 83/200
#  - 1s - loss: 0.0650 - acc: 0.9729 - val_loss: 1.4363 - val_acc: 0.6737
# Epoch 84/200
#  - 1s - loss: 0.0483 - acc: 0.9910 - val_loss: 1.4357 - val_acc: 0.6737
# Epoch 85/200
#  - 1s - loss: 0.0641 - acc: 0.9774 - val_loss: 1.4354 - val_acc: 0.6737
# Epoch 86/200
#  - 1s - loss: 0.0736 - acc: 0.9707 - val_loss: 1.4360 - val_acc: 0.6737
# Epoch 87/200
#  - 1s - loss: 0.0666 - acc: 0.9797 - val_loss: 1.4351 - val_acc: 0.6737
# Epoch 88/200
#  - 1s - loss: 0.0461 - acc: 0.9932 - val_loss: 1.4340 - val_acc: 0.6737
# Epoch 89/200
#  - 1s - loss: 0.0628 - acc: 0.9819 - val_loss: 1.4346 - val_acc: 0.6737
# Epoch 90/200
#  - 1s - loss: 0.0585 - acc: 0.9819 - val_loss: 1.4337 - val_acc: 0.6737
# Epoch 91/200
#  - 1s - loss: 0.0642 - acc: 0.9774 - val_loss: 1.4339 - val_acc: 0.6737
# Epoch 92/200
#  - 1s - loss: 0.0631 - acc: 0.9797 - val_loss: 1.4343 - val_acc: 0.6737
# Epoch 93/200
#  - 1s - loss: 0.0487 - acc: 0.9887 - val_loss: 1.4355 - val_acc: 0.6737
# Epoch 94/200
#  - 1s - loss: 0.0679 - acc: 0.9684 - val_loss: 1.4350 - val_acc: 0.6737
# Epoch 95/200
#  - 1s - loss: 0.0679 - acc: 0.9729 - val_loss: 1.4337 - val_acc: 0.6737
# Epoch 96/200
#  - 1s - loss: 0.0672 - acc: 0.9774 - val_loss: 1.4334 - val_acc: 0.6737
# Epoch 97/200
#  - 1s - loss: 0.0950 - acc: 0.9729 - val_loss: 1.4330 - val_acc: 0.6737
# Epoch 98/200
#  - 1s - loss: 0.0427 - acc: 0.9865 - val_loss: 1.4323 - val_acc: 0.6737
# Epoch 99/200
#  - 1s - loss: 0.0675 - acc: 0.9729 - val_loss: 1.4308 - val_acc: 0.6737
# Epoch 100/200
#  - 1s - loss: 0.0650 - acc: 0.9774 - val_loss: 1.4302 - val_acc: 0.6737
# Epoch 101/200
#  - 1s - loss: 0.0562 - acc: 0.9819 - val_loss: 1.4303 - val_acc: 0.6737
# Epoch 102/200
#  - 1s - loss: 0.0708 - acc: 0.9774 - val_loss: 1.4307 - val_acc: 0.6737
# Epoch 103/200
#  - 1s - loss: 0.0703 - acc: 0.9819 - val_loss: 1.4304 - val_acc: 0.6737
# Epoch 104/200
#  - 1s - loss: 0.0579 - acc: 0.9774 - val_loss: 1.4299 - val_acc: 0.6737
# Epoch 105/200
#  - 1s - loss: 0.0506 - acc: 0.9819 - val_loss: 1.4292 - val_acc: 0.6737
# Epoch 106/200
#  - 1s - loss: 0.0570 - acc: 0.9797 - val_loss: 1.4287 - val_acc: 0.6737
# Epoch 107/200
#  - 1s - loss: 0.0586 - acc: 0.9774 - val_loss: 1.4287 - val_acc: 0.6737
# Epoch 108/200
#  - 1s - loss: 0.0563 - acc: 0.9774 - val_loss: 1.4292 - val_acc: 0.6737
# Epoch 109/200
#  - 1s - loss: 0.0668 - acc: 0.9842 - val_loss: 1.4288 - val_acc: 0.6737
# Epoch 110/200
#  - 1s - loss: 0.0564 - acc: 0.9774 - val_loss: 1.4296 - val_acc: 0.6737
# Epoch 111/200
#  - 1s - loss: 0.0542 - acc: 0.9865 - val_loss: 1.4297 - val_acc: 0.6737
# Epoch 112/200
#  - 1s - loss: 0.0542 - acc: 0.9842 - val_loss: 1.4289 - val_acc: 0.6789
# Epoch 113/200
#  - 1s - loss: 0.0539 - acc: 0.9865 - val_loss: 1.4288 - val_acc: 0.6789
# Epoch 114/200
#  - 1s - loss: 0.0583 - acc: 0.9819 - val_loss: 1.4293 - val_acc: 0.6737
# Epoch 115/200
#  - 1s - loss: 0.0569 - acc: 0.9819 - val_loss: 1.4303 - val_acc: 0.6737
# Epoch 116/200
#  - 1s - loss: 0.0492 - acc: 0.9819 - val_loss: 1.4302 - val_acc: 0.6737
# Epoch 117/200
#  - 1s - loss: 0.0744 - acc: 0.9774 - val_loss: 1.4298 - val_acc: 0.6737
# Epoch 118/200
#  - 1s - loss: 0.0451 - acc: 0.9887 - val_loss: 1.4298 - val_acc: 0.6737

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
