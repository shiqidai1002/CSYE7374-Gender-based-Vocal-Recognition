# %%
import os
from Audio_reader import readtf
from getman import getmanlist
import gc
import numpy as np
import pandas as pd
import pickle
from keras.layers import Dense, Input, Dropout,Flatten,MaxPooling1D
from keras.layers import Conv1D, MaxPooling2D,BatchNormalization,Conv2D
from keras.models import Model
from keras.models import Sequential
from keras import optimizers
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras import regularizers

# %%
def check(y):
    if 74 in y:
        return 0 
    #male
    if 1 in y:
        return 1
    #female
    if 2 in y:
        return 2
    #child
    if 3 in y:
        return 3
    return 0

# %%
X = []
Y = [] 
with open("X_list_eval.pickle","rb") as xf:
    X.extend(pickle.load(xf))
with open("Y_list_eval.pickle","rb") as xf:
    Y.extend(pickle.load(xf))
      
with open("X_list.pickle","rb") as xf:
    X.extend(pickle.load(xf))
with open("Y_list.pickle","rb") as xf:
    Y.extend(pickle.load(xf))

X=np.array(X)
Y=np.array(Y)  

X = X.astype('float32')    
X /= 128

# %%
learning_rate=0.0003
#decay=0.000001
momentum=0.99
dropout_rate = 0.25

rglrzr = regularizers.l2(0.0012)

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same',activation='relu',input_shape=X.shape[1:]))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=dropout_rate))

model.add(Conv2D(128, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(Dropout(rate=dropout_rate))



model.add(Conv2D(256, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=dropout_rate))


model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(Dropout(rate=dropout_rate))



model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(Dropout(rate=dropout_rate))




model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(3,activation='softmax'))
model.summary()

optimizer = optimizers.SGD(lr=learning_rate,momentum=momentum)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer, 
              metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_240 (Conv2D)          (None, 10, 128, 64)       640
# _________________________________________________________________
# batch_normalization_238 (Bat (None, 10, 128, 64)       256
# _________________________________________________________________
# max_pooling2d_123 (MaxPoolin (None, 5, 64, 64)         0
# _________________________________________________________________
# dropout_126 (Dropout)        (None, 5, 64, 64)         0
# _________________________________________________________________
# conv2d_241 (Conv2D)          (None, 5, 64, 128)        73856
# _________________________________________________________________
# batch_normalization_239 (Bat (None, 5, 64, 128)        512
# _________________________________________________________________
# max_pooling2d_124 (MaxPoolin (None, 5, 32, 128)        0
# _________________________________________________________________
# dropout_127 (Dropout)        (None, 5, 32, 128)        0
# _________________________________________________________________
# conv2d_242 (Conv2D)          (None, 5, 32, 256)        295168
# _________________________________________________________________
# batch_normalization_240 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# conv2d_243 (Conv2D)          (None, 5, 32, 256)        590080
# _________________________________________________________________
# batch_normalization_241 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# max_pooling2d_125 (MaxPoolin (None, 2, 16, 256)        0
# _________________________________________________________________
# dropout_128 (Dropout)        (None, 2, 16, 256)        0
# _________________________________________________________________
# conv2d_244 (Conv2D)          (None, 2, 16, 512)        1180160
# _________________________________________________________________
# batch_normalization_242 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# conv2d_245 (Conv2D)          (None, 2, 16, 512)        2359808
# _________________________________________________________________
# batch_normalization_243 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# max_pooling2d_126 (MaxPoolin (None, 2, 8, 512)         0
# _________________________________________________________________
# dropout_129 (Dropout)        (None, 2, 8, 512)         0
# _________________________________________________________________
# conv2d_246 (Conv2D)          (None, 2, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_244 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# conv2d_247 (Conv2D)          (None, 2, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_245 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# max_pooling2d_127 (MaxPoolin (None, 2, 4, 512)         0
# _________________________________________________________________
# dropout_130 (Dropout)        (None, 2, 4, 512)         0
# _________________________________________________________________
# flatten_37 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_74 (Dense)             (None, 128)               524416
# _________________________________________________________________
# dense_75 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 9,755,139
# Trainable params: 9,749,635
# Non-trainable params: 5,504
# _________________________________________________________________

# %%
cb=[]

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=3, verbose=0, mode='auto')
early_stopping = EarlyStopping(monitor='acc', min_delta=0, patience=30, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

cb.append(reduce_lr)
cb.append(early_stopping)

# %%
history=model.fit(X, Y,
          batch_size=32,
          epochs=200,
          verbose=2,
          callbacks=cb,
          validation_split=0.3)
# Out:
# Train on 443 samples, validate on 190 samples
# Epoch 1/200
#  - 14s - loss: 1.7019 - acc: 0.4582 - val_loss: 2.3091 - val_acc: 0.2526
# Epoch 2/200
#  - 1s - loss: 1.3630 - acc: 0.4921 - val_loss: 1.1501 - val_acc: 0.5895
# Epoch 3/200
#  - 1s - loss: 1.0990 - acc: 0.5530 - val_loss: 1.4826 - val_acc: 0.2158
# Epoch 4/200
#  - 1s - loss: 0.9866 - acc: 0.5327 - val_loss: 2.2636 - val_acc: 0.5789
# Epoch 5/200
#  - 1s - loss: 0.9777 - acc: 0.5937 - val_loss: 2.7635 - val_acc: 0.5789
# Epoch 6/200
#  - 1s - loss: 0.9212 - acc: 0.5959 - val_loss: 2.1023 - val_acc: 0.2421
# Epoch 7/200
#  - 1s - loss: 0.8841 - acc: 0.5937 - val_loss: 2.3890 - val_acc: 0.1947
# Epoch 8/200
#  - 1s - loss: 0.8626 - acc: 0.6117 - val_loss: 1.7110 - val_acc: 0.5789
# Epoch 9/200
#  - 1s - loss: 0.8520 - acc: 0.6275 - val_loss: 1.2252 - val_acc: 0.5789
# Epoch 10/200
#  - 1s - loss: 0.8363 - acc: 0.6230 - val_loss: 1.1308 - val_acc: 0.3263
# Epoch 11/200
#  - 1s - loss: 0.8205 - acc: 0.6321 - val_loss: 1.2874 - val_acc: 0.2789
# Epoch 12/200
#  - 1s - loss: 0.8045 - acc: 0.6479 - val_loss: 1.1413 - val_acc: 0.4000
# Epoch 13/200
#  - 1s - loss: 0.7939 - acc: 0.6501 - val_loss: 1.2911 - val_acc: 0.5789
# Epoch 14/200
#  - 1s - loss: 0.7704 - acc: 0.6659 - val_loss: 1.6445 - val_acc: 0.5789
# Epoch 15/200
#  - 1s - loss: 0.7653 - acc: 0.6727 - val_loss: 1.4243 - val_acc: 0.5842
# Epoch 16/200
#  - 1s - loss: 0.7285 - acc: 0.6795 - val_loss: 1.2816 - val_acc: 0.5579
# Epoch 17/200
#  - 1s - loss: 0.6972 - acc: 0.7178 - val_loss: 1.2398 - val_acc: 0.5263
# Epoch 18/200
#  - 1s - loss: 0.6752 - acc: 0.7088 - val_loss: 1.2598 - val_acc: 0.5368
# Epoch 19/200
#  - 1s - loss: 0.6559 - acc: 0.7178 - val_loss: 1.2301 - val_acc: 0.5684
# Epoch 20/200
#  - 1s - loss: 0.6659 - acc: 0.7088 - val_loss: 1.1490 - val_acc: 0.5789
# Epoch 21/200
#  - 1s - loss: 0.6351 - acc: 0.7359 - val_loss: 1.1165 - val_acc: 0.5947
# Epoch 22/200
#  - 1s - loss: 0.5911 - acc: 0.7585 - val_loss: 1.1158 - val_acc: 0.6211
# Epoch 23/200
#  - 1s - loss: 0.5792 - acc: 0.7698 - val_loss: 1.0607 - val_acc: 0.5842
# Epoch 24/200
#  - 1s - loss: 0.5958 - acc: 0.7427 - val_loss: 1.0992 - val_acc: 0.5684
# Epoch 25/200
#  - 1s - loss: 0.5202 - acc: 0.8014 - val_loss: 1.1289 - val_acc: 0.5947
# Epoch 26/200
#  - 1s - loss: 0.5097 - acc: 0.7878 - val_loss: 1.0435 - val_acc: 0.6000
# Epoch 27/200
#  - 1s - loss: 0.4752 - acc: 0.8014 - val_loss: 0.9615 - val_acc: 0.6211
# Epoch 28/200
#  - 1s - loss: 0.4577 - acc: 0.8104 - val_loss: 0.9439 - val_acc: 0.6368
# Epoch 29/200
#  - 1s - loss: 0.4410 - acc: 0.8217 - val_loss: 0.9367 - val_acc: 0.6474
# Epoch 30/200
#  - 1s - loss: 0.3984 - acc: 0.8510 - val_loss: 1.0063 - val_acc: 0.6316
# Epoch 31/200
#  - 1s - loss: 0.4114 - acc: 0.8533 - val_loss: 0.9937 - val_acc: 0.6263
# Epoch 32/200
#  - 1s - loss: 0.3357 - acc: 0.8736 - val_loss: 0.9094 - val_acc: 0.6474
# Epoch 33/200
#  - 1s - loss: 0.3409 - acc: 0.8758 - val_loss: 0.9021 - val_acc: 0.6684
# Epoch 34/200
#  - 1s - loss: 0.3271 - acc: 0.8668 - val_loss: 0.9245 - val_acc: 0.6632
# Epoch 35/200
#  - 1s - loss: 0.3010 - acc: 0.9120 - val_loss: 0.9546 - val_acc: 0.6737
# Epoch 36/200
#  - 1s - loss: 0.2686 - acc: 0.9074 - val_loss: 0.9497 - val_acc: 0.6737
# Epoch 37/200
#  - 1s - loss: 0.2373 - acc: 0.9233 - val_loss: 0.9362 - val_acc: 0.6895
# Epoch 38/200
#  - 1s - loss: 0.2628 - acc: 0.9120 - val_loss: 0.9656 - val_acc: 0.6526
# Epoch 39/200
#  - 1s - loss: 0.2232 - acc: 0.9142 - val_loss: 0.9792 - val_acc: 0.6474
# Epoch 40/200
#  - 1s - loss: 0.2140 - acc: 0.9323 - val_loss: 1.0088 - val_acc: 0.6421
# Epoch 41/200
#  - 1s - loss: 0.1739 - acc: 0.9391 - val_loss: 1.0416 - val_acc: 0.6789
# Epoch 42/200
#  - 1s - loss: 0.1881 - acc: 0.9233 - val_loss: 1.0722 - val_acc: 0.6789
# Epoch 43/200
#  - 1s - loss: 0.1615 - acc: 0.9436 - val_loss: 1.0935 - val_acc: 0.6895
# Epoch 44/200
#  - 1s - loss: 0.1621 - acc: 0.9368 - val_loss: 1.0831 - val_acc: 0.6737
# Epoch 45/200
#  - 1s - loss: 0.1685 - acc: 0.9368 - val_loss: 1.0991 - val_acc: 0.6947
# Epoch 46/200
#  - 1s - loss: 0.1439 - acc: 0.9503 - val_loss: 1.1407 - val_acc: 0.6579
# Epoch 47/200
#  - 1s - loss: 0.1396 - acc: 0.9526 - val_loss: 1.1679 - val_acc: 0.6684
# Epoch 48/200
#  - 1s - loss: 0.1149 - acc: 0.9639 - val_loss: 1.1846 - val_acc: 0.6789
# Epoch 49/200
#  - 1s - loss: 0.1182 - acc: 0.9503 - val_loss: 1.2058 - val_acc: 0.7000
# Epoch 50/200
#  - 1s - loss: 0.1262 - acc: 0.9481 - val_loss: 1.2004 - val_acc: 0.7211
# Epoch 51/200
#  - 1s - loss: 0.1252 - acc: 0.9526 - val_loss: 1.1799 - val_acc: 0.7053
# Epoch 52/200
#  - 1s - loss: 0.0859 - acc: 0.9819 - val_loss: 1.1651 - val_acc: 0.6789
# Epoch 53/200
#  - 1s - loss: 0.0961 - acc: 0.9639 - val_loss: 1.1653 - val_acc: 0.6737
# Epoch 54/200
#  - 1s - loss: 0.1013 - acc: 0.9594 - val_loss: 1.1679 - val_acc: 0.6579
# Epoch 55/200
#  - 1s - loss: 0.0935 - acc: 0.9774 - val_loss: 1.1704 - val_acc: 0.6579
# Epoch 56/200
#  - 1s - loss: 0.0866 - acc: 0.9797 - val_loss: 1.1798 - val_acc: 0.6947
# Epoch 57/200
#  - 1s - loss: 0.0938 - acc: 0.9752 - val_loss: 1.1980 - val_acc: 0.6947
# Epoch 58/200
#  - 1s - loss: 0.0738 - acc: 0.9797 - val_loss: 1.2063 - val_acc: 0.6947
# Epoch 59/200
#  - 1s - loss: 0.0746 - acc: 0.9729 - val_loss: 1.2105 - val_acc: 0.6895
# Epoch 60/200
#  - 1s - loss: 0.0697 - acc: 0.9865 - val_loss: 1.2081 - val_acc: 0.6842
# Epoch 61/200
#  - 1s - loss: 0.0769 - acc: 0.9797 - val_loss: 1.2092 - val_acc: 0.6842
# Epoch 62/200
#  - 1s - loss: 0.0769 - acc: 0.9707 - val_loss: 1.2096 - val_acc: 0.6947
# Epoch 63/200
#  - 1s - loss: 0.0483 - acc: 0.9932 - val_loss: 1.2103 - val_acc: 0.6842
# Epoch 64/200
#  - 1s - loss: 0.0657 - acc: 0.9819 - val_loss: 1.2175 - val_acc: 0.6684
# Epoch 65/200
#  - 1s - loss: 0.0687 - acc: 0.9774 - val_loss: 1.2350 - val_acc: 0.6737
# Epoch 66/200
#  - 1s - loss: 0.0694 - acc: 0.9797 - val_loss: 1.2593 - val_acc: 0.6684
# Epoch 67/200
#  - 1s - loss: 0.0670 - acc: 0.9842 - val_loss: 1.2834 - val_acc: 0.6632
# Epoch 68/200
#  - 1s - loss: 0.0702 - acc: 0.9774 - val_loss: 1.3059 - val_acc: 0.6632
# Epoch 69/200
#  - 1s - loss: 0.0683 - acc: 0.9819 - val_loss: 1.3171 - val_acc: 0.6737
# Epoch 70/200
#  - 1s - loss: 0.0530 - acc: 0.9842 - val_loss: 1.3262 - val_acc: 0.6789
# Epoch 71/200
#  - 1s - loss: 0.0496 - acc: 0.9865 - val_loss: 1.3330 - val_acc: 0.6737
# Epoch 72/200
#  - 1s - loss: 0.0551 - acc: 0.9819 - val_loss: 1.3363 - val_acc: 0.6842
# Epoch 73/200
#  - 1s - loss: 0.0664 - acc: 0.9865 - val_loss: 1.3340 - val_acc: 0.6789
# Epoch 74/200
#  - 1s - loss: 0.0632 - acc: 0.9842 - val_loss: 1.3296 - val_acc: 0.6737
# Epoch 75/200
#  - 1s - loss: 0.0628 - acc: 0.9842 - val_loss: 1.3267 - val_acc: 0.6789
# Epoch 76/200
#  - 1s - loss: 0.0388 - acc: 0.9932 - val_loss: 1.3249 - val_acc: 0.6789
# Epoch 77/200
#  - 1s - loss: 0.0554 - acc: 0.9865 - val_loss: 1.3234 - val_acc: 0.6842
# Epoch 78/200
#  - 1s - loss: 0.0514 - acc: 0.9842 - val_loss: 1.3226 - val_acc: 0.6842
# Epoch 79/200
#  - 1s - loss: 0.0479 - acc: 0.9819 - val_loss: 1.3208 - val_acc: 0.6947
# Epoch 80/200
#  - 1s - loss: 0.0546 - acc: 0.9797 - val_loss: 1.3190 - val_acc: 0.6947
# Epoch 81/200
#  - 1s - loss: 0.0514 - acc: 0.9865 - val_loss: 1.3159 - val_acc: 0.7000
# Epoch 82/200
#  - 1s - loss: 0.0576 - acc: 0.9797 - val_loss: 1.3140 - val_acc: 0.7000
# Epoch 83/200
#  - 1s - loss: 0.0508 - acc: 0.9797 - val_loss: 1.3102 - val_acc: 0.7000
# Epoch 84/200
#  - 1s - loss: 0.0419 - acc: 0.9910 - val_loss: 1.3072 - val_acc: 0.7000
# Epoch 85/200
#  - 1s - loss: 0.0481 - acc: 0.9842 - val_loss: 1.3028 - val_acc: 0.7000
# Epoch 86/200
#  - 1s - loss: 0.0420 - acc: 0.9887 - val_loss: 1.2975 - val_acc: 0.7000
# Epoch 87/200
#  - 1s - loss: 0.0437 - acc: 0.9910 - val_loss: 1.2924 - val_acc: 0.7000
# Epoch 88/200
#  - 1s - loss: 0.0481 - acc: 0.9887 - val_loss: 1.2874 - val_acc: 0.6947
# Epoch 89/200
#  - 1s - loss: 0.0486 - acc: 0.9842 - val_loss: 1.2836 - val_acc: 0.6947
# Epoch 90/200
#  - 1s - loss: 0.0451 - acc: 0.9955 - val_loss: 1.2807 - val_acc: 0.6842
# Epoch 91/200
#  - 1s - loss: 0.0519 - acc: 0.9819 - val_loss: 1.2780 - val_acc: 0.6842
# Epoch 92/200
#  - 1s - loss: 0.0417 - acc: 0.9887 - val_loss: 1.2774 - val_acc: 0.6842
# Epoch 93/200
#  - 1s - loss: 0.0420 - acc: 0.9887 - val_loss: 1.2771 - val_acc: 0.6842
# Epoch 94/200
#  - 1s - loss: 0.0596 - acc: 0.9819 - val_loss: 1.2761 - val_acc: 0.6789
# Epoch 95/200
#  - 1s - loss: 0.0425 - acc: 0.9910 - val_loss: 1.2760 - val_acc: 0.6789
# Epoch 96/200
#  - 1s - loss: 0.0412 - acc: 0.9910 - val_loss: 1.2763 - val_acc: 0.6789
# Epoch 97/200
#  - 1s - loss: 0.0418 - acc: 0.9887 - val_loss: 1.2781 - val_acc: 0.6789
# Epoch 98/200
#  - 1s - loss: 0.0634 - acc: 0.9774 - val_loss: 1.2786 - val_acc: 0.6789
# Epoch 99/200
#  - 1s - loss: 0.0432 - acc: 0.9842 - val_loss: 1.2792 - val_acc: 0.6789
# Epoch 100/200
#  - 1s - loss: 0.0478 - acc: 0.9865 - val_loss: 1.2800 - val_acc: 0.6789
# Epoch 101/200
#  - 1s - loss: 0.0445 - acc: 0.9865 - val_loss: 1.2811 - val_acc: 0.6789
# Epoch 102/200
#  - 1s - loss: 0.0412 - acc: 0.9887 - val_loss: 1.2819 - val_acc: 0.6789
# Epoch 103/200
#  - 1s - loss: 0.0624 - acc: 0.9774 - val_loss: 1.2824 - val_acc: 0.6789
# Epoch 104/200
#  - 1s - loss: 0.0401 - acc: 0.9887 - val_loss: 1.2833 - val_acc: 0.6789
# Epoch 105/200
#  - 1s - loss: 0.0600 - acc: 0.9865 - val_loss: 1.2845 - val_acc: 0.6789
# Epoch 106/200
#  - 1s - loss: 0.0447 - acc: 0.9865 - val_loss: 1.2858 - val_acc: 0.6789
# Epoch 107/200
#  - 1s - loss: 0.0445 - acc: 0.9865 - val_loss: 1.2870 - val_acc: 0.6789
# Epoch 108/200
#  - 1s - loss: 0.0509 - acc: 0.9887 - val_loss: 1.2875 - val_acc: 0.6789
# Epoch 109/200
#  - 1s - loss: 0.0633 - acc: 0.9819 - val_loss: 1.2883 - val_acc: 0.6789
# Epoch 110/200
#  - 1s - loss: 0.0406 - acc: 0.9910 - val_loss: 1.2891 - val_acc: 0.6789
# Epoch 111/200
#  - 1s - loss: 0.0453 - acc: 0.9910 - val_loss: 1.2895 - val_acc: 0.6789
# Epoch 112/200
#  - 1s - loss: 0.0546 - acc: 0.9774 - val_loss: 1.2905 - val_acc: 0.6789
# Epoch 113/200
#  - 1s - loss: 0.0431 - acc: 0.9887 - val_loss: 1.2918 - val_acc: 0.6789
# Epoch 114/200
#  - 1s - loss: 0.0427 - acc: 0.9910 - val_loss: 1.2924 - val_acc: 0.6789
# Epoch 115/200
#  - 1s - loss: 0.0420 - acc: 0.9910 - val_loss: 1.2931 - val_acc: 0.6789
# Epoch 116/200
#  - 1s - loss: 0.0511 - acc: 0.9887 - val_loss: 1.2942 - val_acc: 0.6789
# Epoch 117/200
#  - 1s - loss: 0.0498 - acc: 0.9910 - val_loss: 1.2938 - val_acc: 0.6789
# Epoch 118/200
#  - 1s - loss: 0.0572 - acc: 0.9842 - val_loss: 1.2945 - val_acc: 0.6789
# Epoch 119/200
#  - 1s - loss: 0.0519 - acc: 0.9819 - val_loss: 1.2951 - val_acc: 0.6789
# Epoch 120/200
#  - 1s - loss: 0.0437 - acc: 0.9887 - val_loss: 1.2948 - val_acc: 0.6789

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
