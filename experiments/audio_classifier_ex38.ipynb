# %%
import os
from Audio_reader import readtf
from getman import getmanlist
import gc
import numpy as np
import pandas as pd
import pickle
from keras.layers import Dense, Input, Dropout,Flatten,MaxPooling1D,SpatialDropout2D
from keras.layers import Conv1D, MaxPooling2D,BatchNormalization,Conv2D
from keras.models import Model
from keras.models import Sequential
from keras import optimizers
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras import regularizers

# %%
def check(y):
    if 74 in y:
        return 0 
    #male
    if 1 in y:
        return 1
    #female
    if 2 in y:
        return 2
    #child
    if 3 in y:
        return 3
    return 0

# %%
X = []
Y = [] 
with open("X_list_eval.pickle","rb") as xf:
    X.extend(pickle.load(xf))
with open("Y_list_eval.pickle","rb") as xf:
    Y.extend(pickle.load(xf))
      
with open("X_list.pickle","rb") as xf:
    X.extend(pickle.load(xf))
with open("Y_list.pickle","rb") as xf:
    Y.extend(pickle.load(xf))

X=np.array(X)
Y=np.array(Y)  

X = X.astype('float32')    
X /= 128

# %%
learning_rate=0.001
#decay=0.000001
momentum=0.99
dropout_rate = 0.35

rglrzr = regularizers.l2(0.0015)

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same',activation='relu',input_shape=X.shape[1:]))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(SpatialDropout2D(rate=dropout_rate))

model.add(Conv2D(128, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(SpatialDropout2D(rate=dropout_rate))



model.add(Conv2D(256, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(SpatialDropout2D(rate=dropout_rate))


model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(SpatialDropout2D(rate=dropout_rate))



model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same',activation='relu',bias_regularizer=rglrzr))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(1, 2)))
model.add(SpatialDropout2D(rate=dropout_rate))




model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(3,activation='softmax'))
model.summary()

optimizer = optimizers.SGD(lr=learning_rate,momentum=momentum)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer, 
              metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_353 (Conv2D)          (None, 10, 128, 64)       640
# _________________________________________________________________
# batch_normalization_351 (Bat (None, 10, 128, 64)       256
# _________________________________________________________________
# max_pooling2d_194 (MaxPoolin (None, 5, 64, 64)         0
# _________________________________________________________________
# spatial_dropout2d_36 (Spatia (None, 5, 64, 64)         0
# _________________________________________________________________
# conv2d_354 (Conv2D)          (None, 5, 64, 128)        73856
# _________________________________________________________________
# batch_normalization_352 (Bat (None, 5, 64, 128)        512
# _________________________________________________________________
# max_pooling2d_195 (MaxPoolin (None, 5, 32, 128)        0
# _________________________________________________________________
# spatial_dropout2d_37 (Spatia (None, 5, 32, 128)        0
# _________________________________________________________________
# conv2d_355 (Conv2D)          (None, 5, 32, 256)        295168
# _________________________________________________________________
# batch_normalization_353 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# conv2d_356 (Conv2D)          (None, 5, 32, 256)        590080
# _________________________________________________________________
# batch_normalization_354 (Bat (None, 5, 32, 256)        1024
# _________________________________________________________________
# max_pooling2d_196 (MaxPoolin (None, 2, 16, 256)        0
# _________________________________________________________________
# spatial_dropout2d_38 (Spatia (None, 2, 16, 256)        0
# _________________________________________________________________
# conv2d_357 (Conv2D)          (None, 2, 16, 512)        1180160
# _________________________________________________________________
# batch_normalization_355 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# conv2d_358 (Conv2D)          (None, 2, 16, 512)        2359808
# _________________________________________________________________
# batch_normalization_356 (Bat (None, 2, 16, 512)        2048
# _________________________________________________________________
# max_pooling2d_197 (MaxPoolin (None, 2, 8, 512)         0
# _________________________________________________________________
# spatial_dropout2d_39 (Spatia (None, 2, 8, 512)         0
# _________________________________________________________________
# conv2d_359 (Conv2D)          (None, 2, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_357 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# conv2d_360 (Conv2D)          (None, 2, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_358 (Bat (None, 2, 8, 512)         2048
# _________________________________________________________________
# max_pooling2d_198 (MaxPoolin (None, 2, 4, 512)         0
# _________________________________________________________________
# spatial_dropout2d_40 (Spatia (None, 2, 4, 512)         0
# _________________________________________________________________
# flatten_51 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_102 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_103 (Dense)            (None, 3)                 387
# =================================================================
# Total params: 9,755,139
# Trainable params: 9,749,635
# Non-trainable params: 5,504
# _________________________________________________________________

# %%
cb=[]

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.85, patience=3, verbose=0, mode='auto')
early_stopping = EarlyStopping(monitor='acc', min_delta=0, patience=30, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

cb.append(reduce_lr)
cb.append(early_stopping)

# %%
history=model.fit(X, Y,
          batch_size=32,
          epochs=200,
          verbose=2,
          callbacks=cb,
          validation_split=0.2,
          shuffle=True)
# Out:
# Train on 506 samples, validate on 127 samples
# Epoch 1/200
#  - 21s - loss: 1.6412 - acc: 0.4387 - val_loss: 1.5256 - val_acc: 0.2677
# Epoch 2/200
#  - 1s - loss: 1.1719 - acc: 0.5079 - val_loss: 3.3752 - val_acc: 0.2362
# Epoch 3/200
#  - 1s - loss: 1.0400 - acc: 0.5692 - val_loss: 9.0438 - val_acc: 0.2362
# Epoch 4/200
#  - 1s - loss: 0.9893 - acc: 0.5474 - val_loss: 6.0266 - val_acc: 0.2362
# Epoch 5/200
#  - 1s - loss: 0.9436 - acc: 0.5949 - val_loss: 7.7418 - val_acc: 0.5197
# Epoch 6/200
#  - 1s - loss: 0.8892 - acc: 0.6107 - val_loss: 2.6189 - val_acc: 0.4646
# Epoch 7/200
#  - 1s - loss: 0.8873 - acc: 0.6107 - val_loss: 4.7984 - val_acc: 0.5197
# Epoch 8/200
#  - 1s - loss: 0.8690 - acc: 0.6028 - val_loss: 4.4517 - val_acc: 0.2362
# Epoch 9/200
#  - 1s - loss: 0.9014 - acc: 0.5751 - val_loss: 2.2771 - val_acc: 0.2362
# Epoch 10/200
#  - 1s - loss: 0.8982 - acc: 0.5949 - val_loss: 1.5919 - val_acc: 0.5197
# Epoch 11/200
#  - 1s - loss: 0.8625 - acc: 0.6285 - val_loss: 1.0814 - val_acc: 0.5197
# Epoch 12/200
#  - 1s - loss: 0.8620 - acc: 0.6285 - val_loss: 1.0937 - val_acc: 0.5039
# Epoch 13/200
#  - 1s - loss: 0.8574 - acc: 0.6146 - val_loss: 1.1727 - val_acc: 0.5039
# Epoch 14/200
#  - 1s - loss: 0.8294 - acc: 0.6482 - val_loss: 1.2680 - val_acc: 0.5118
# Epoch 15/200
#  - 1s - loss: 0.8391 - acc: 0.6364 - val_loss: 1.3557 - val_acc: 0.3701
# Epoch 16/200
#  - 1s - loss: 0.7993 - acc: 0.6383 - val_loss: 1.3019 - val_acc: 0.3386
# Epoch 17/200
#  - 1s - loss: 0.7882 - acc: 0.6561 - val_loss: 1.2441 - val_acc: 0.4646
# Epoch 18/200
#  - 1s - loss: 0.8011 - acc: 0.6542 - val_loss: 1.1980 - val_acc: 0.4803
# Epoch 19/200
#  - 1s - loss: 0.7754 - acc: 0.6581 - val_loss: 1.1264 - val_acc: 0.4252
# Epoch 20/200
#  - 1s - loss: 0.7842 - acc: 0.6383 - val_loss: 1.0578 - val_acc: 0.4803
# Epoch 21/200
#  - 1s - loss: 0.7480 - acc: 0.6838 - val_loss: 1.1136 - val_acc: 0.5039
# Epoch 22/200
#  - 1s - loss: 0.7515 - acc: 0.6719 - val_loss: 1.0928 - val_acc: 0.5118
# Epoch 23/200
#  - 1s - loss: 0.7365 - acc: 0.6660 - val_loss: 1.0801 - val_acc: 0.4724
# Epoch 24/200
#  - 1s - loss: 0.7051 - acc: 0.7055 - val_loss: 0.9955 - val_acc: 0.4961
# Epoch 25/200
#  - 1s - loss: 0.7257 - acc: 0.6542 - val_loss: 0.9717 - val_acc: 0.4961
# Epoch 26/200
#  - 1s - loss: 0.6703 - acc: 0.6976 - val_loss: 0.9993 - val_acc: 0.5118
# Epoch 27/200
#  - 1s - loss: 0.6903 - acc: 0.7134 - val_loss: 0.9745 - val_acc: 0.5433
# Epoch 28/200
#  - 1s - loss: 0.6720 - acc: 0.7194 - val_loss: 0.9377 - val_acc: 0.5669
# Epoch 29/200
#  - 1s - loss: 0.6752 - acc: 0.7075 - val_loss: 0.8760 - val_acc: 0.5906
# Epoch 30/200
#  - 1s - loss: 0.6016 - acc: 0.7411 - val_loss: 0.9022 - val_acc: 0.5669
# Epoch 31/200
#  - 1s - loss: 0.6362 - acc: 0.7273 - val_loss: 0.9157 - val_acc: 0.5906
# Epoch 32/200
#  - 1s - loss: 0.6213 - acc: 0.7549 - val_loss: 0.8465 - val_acc: 0.6220
# Epoch 33/200
#  - 1s - loss: 0.6188 - acc: 0.7530 - val_loss: 0.8541 - val_acc: 0.6220
# Epoch 34/200
#  - 1s - loss: 0.5902 - acc: 0.7609 - val_loss: 0.9702 - val_acc: 0.5827
# Epoch 35/200
#  - 1s - loss: 0.5889 - acc: 0.7431 - val_loss: 0.8706 - val_acc: 0.6299
# Epoch 36/200
#  - 1s - loss: 0.5753 - acc: 0.7470 - val_loss: 0.8402 - val_acc: 0.6535
# Epoch 37/200
#  - 1s - loss: 0.5657 - acc: 0.7806 - val_loss: 0.9490 - val_acc: 0.5984
# Epoch 38/200
#  - 1s - loss: 0.5478 - acc: 0.7767 - val_loss: 0.9461 - val_acc: 0.5906
# Epoch 39/200
#  - 1s - loss: 0.5720 - acc: 0.7628 - val_loss: 0.9152 - val_acc: 0.6299
# Epoch 40/200
#  - 1s - loss: 0.5084 - acc: 0.7905 - val_loss: 0.8869 - val_acc: 0.6535
# Epoch 41/200
#  - 1s - loss: 0.4911 - acc: 0.7905 - val_loss: 0.8906 - val_acc: 0.6457
# Epoch 42/200
#  - 1s - loss: 0.4507 - acc: 0.8123 - val_loss: 0.9193 - val_acc: 0.6378
# Epoch 43/200
#  - 1s - loss: 0.4727 - acc: 0.8063 - val_loss: 0.9137 - val_acc: 0.6535
# Epoch 44/200
#  - 1s - loss: 0.4719 - acc: 0.8004 - val_loss: 0.8347 - val_acc: 0.6614
# Epoch 45/200
#  - 1s - loss: 0.4458 - acc: 0.8142 - val_loss: 0.8090 - val_acc: 0.6614
# Epoch 46/200
#  - 1s - loss: 0.4324 - acc: 0.8360 - val_loss: 0.8322 - val_acc: 0.6535
# Epoch 47/200
#  - 1s - loss: 0.4185 - acc: 0.8202 - val_loss: 0.8866 - val_acc: 0.6378
# Epoch 48/200
#  - 1s - loss: 0.4326 - acc: 0.8221 - val_loss: 0.8893 - val_acc: 0.6535
# Epoch 49/200
#  - 1s - loss: 0.4095 - acc: 0.8419 - val_loss: 0.8692 - val_acc: 0.6614
# Epoch 50/200
#  - 1s - loss: 0.3729 - acc: 0.8478 - val_loss: 0.8786 - val_acc: 0.6535
# Epoch 51/200
#  - 1s - loss: 0.4114 - acc: 0.8399 - val_loss: 0.8959 - val_acc: 0.6457
# Epoch 52/200
#  - 1s - loss: 0.3844 - acc: 0.8379 - val_loss: 0.9196 - val_acc: 0.6535
# Epoch 53/200
#  - 1s - loss: 0.3841 - acc: 0.8300 - val_loss: 0.9403 - val_acc: 0.6457
# Epoch 54/200
#  - 1s - loss: 0.3771 - acc: 0.8676 - val_loss: 0.9577 - val_acc: 0.6378
# Epoch 55/200
#  - 1s - loss: 0.3767 - acc: 0.8538 - val_loss: 0.9558 - val_acc: 0.6457
# Epoch 56/200
#  - 1s - loss: 0.3524 - acc: 0.8656 - val_loss: 0.9471 - val_acc: 0.6614
# Epoch 57/200
#  - 1s - loss: 0.3445 - acc: 0.8696 - val_loss: 0.9710 - val_acc: 0.6614
# Epoch 58/200
#  - 1s - loss: 0.3550 - acc: 0.8676 - val_loss: 1.0227 - val_acc: 0.6535
# Epoch 59/200
#  - 1s - loss: 0.3624 - acc: 0.8538 - val_loss: 1.0427 - val_acc: 0.6378
# Epoch 60/200
#  - 1s - loss: 0.2961 - acc: 0.8913 - val_loss: 1.0323 - val_acc: 0.6535
# Epoch 61/200
#  - 1s - loss: 0.3187 - acc: 0.8775 - val_loss: 1.0209 - val_acc: 0.6614
# Epoch 62/200
#  - 1s - loss: 0.2899 - acc: 0.8972 - val_loss: 1.0139 - val_acc: 0.6693
# Epoch 63/200
#  - 1s - loss: 0.2740 - acc: 0.9150 - val_loss: 1.0047 - val_acc: 0.6614
# Epoch 64/200
#  - 1s - loss: 0.2887 - acc: 0.8834 - val_loss: 1.0043 - val_acc: 0.6693
# Epoch 65/200
#  - 1s - loss: 0.2931 - acc: 0.8893 - val_loss: 1.0131 - val_acc: 0.6614
# Epoch 66/200
#  - 1s - loss: 0.2619 - acc: 0.8874 - val_loss: 1.0178 - val_acc: 0.6693
# Epoch 67/200
#  - 1s - loss: 0.2971 - acc: 0.8775 - val_loss: 1.0223 - val_acc: 0.6614
# Epoch 68/200
#  - 1s - loss: 0.2925 - acc: 0.8874 - val_loss: 1.0370 - val_acc: 0.6614
# Epoch 69/200
#  - 1s - loss: 0.2542 - acc: 0.8972 - val_loss: 1.0526 - val_acc: 0.6693
# Epoch 70/200
#  - 1s - loss: 0.2600 - acc: 0.9012 - val_loss: 1.0831 - val_acc: 0.6535
# Epoch 71/200
#  - 1s - loss: 0.2599 - acc: 0.8992 - val_loss: 1.1050 - val_acc: 0.6772
# Epoch 72/200
#  - 1s - loss: 0.2440 - acc: 0.9071 - val_loss: 1.1093 - val_acc: 0.6535
# Epoch 73/200
#  - 1s - loss: 0.2839 - acc: 0.8854 - val_loss: 1.1216 - val_acc: 0.6378
# Epoch 74/200
#  - 1s - loss: 0.2258 - acc: 0.9170 - val_loss: 1.1437 - val_acc: 0.6299
# Epoch 75/200
#  - 1s - loss: 0.2471 - acc: 0.9071 - val_loss: 1.1784 - val_acc: 0.6457
# Epoch 76/200
#  - 1s - loss: 0.2496 - acc: 0.8972 - val_loss: 1.2106 - val_acc: 0.6457
# Epoch 77/200
#  - 1s - loss: 0.2552 - acc: 0.8992 - val_loss: 1.2230 - val_acc: 0.6535
# Epoch 78/200
#  - 1s - loss: 0.2312 - acc: 0.9130 - val_loss: 1.2269 - val_acc: 0.6535
# Epoch 79/200
#  - 1s - loss: 0.2144 - acc: 0.9209 - val_loss: 1.2140 - val_acc: 0.6535
# Epoch 80/200
#  - 1s - loss: 0.2111 - acc: 0.9190 - val_loss: 1.1931 - val_acc: 0.6535
# Epoch 81/200
#  - 1s - loss: 0.2377 - acc: 0.9150 - val_loss: 1.1780 - val_acc: 0.6693
# Epoch 82/200
#  - 1s - loss: 0.2118 - acc: 0.9269 - val_loss: 1.1675 - val_acc: 0.6693
# Epoch 83/200
#  - 1s - loss: 0.2276 - acc: 0.9269 - val_loss: 1.1687 - val_acc: 0.6693
# Epoch 84/200
#  - 1s - loss: 0.2269 - acc: 0.9032 - val_loss: 1.1741 - val_acc: 0.6614
# Epoch 85/200
#  - 1s - loss: 0.2164 - acc: 0.9328 - val_loss: 1.1815 - val_acc: 0.6614
# Epoch 86/200
#  - 1s - loss: 0.2477 - acc: 0.8972 - val_loss: 1.1884 - val_acc: 0.6614
# Epoch 87/200
#  - 1s - loss: 0.2082 - acc: 0.9249 - val_loss: 1.1981 - val_acc: 0.6693
# Epoch 88/200
#  - 1s - loss: 0.2069 - acc: 0.9130 - val_loss: 1.2013 - val_acc: 0.6693
# Epoch 89/200
#  - 1s - loss: 0.1868 - acc: 0.9229 - val_loss: 1.1964 - val_acc: 0.6693
# Epoch 90/200
#  - 1s - loss: 0.2010 - acc: 0.9229 - val_loss: 1.1947 - val_acc: 0.6693
# Epoch 91/200
#  - 1s - loss: 0.2520 - acc: 0.9091 - val_loss: 1.1944 - val_acc: 0.6693
# Epoch 92/200
#  - 1s - loss: 0.2001 - acc: 0.9466 - val_loss: 1.1942 - val_acc: 0.6693
# Epoch 93/200
#  - 1s - loss: 0.2066 - acc: 0.9111 - val_loss: 1.2016 - val_acc: 0.6693
# Epoch 94/200
#  - 1s - loss: 0.2045 - acc: 0.9209 - val_loss: 1.2060 - val_acc: 0.6693
# Epoch 95/200
#  - 1s - loss: 0.1635 - acc: 0.9368 - val_loss: 1.2089 - val_acc: 0.6693
# Epoch 96/200
#  - 1s - loss: 0.1929 - acc: 0.9229 - val_loss: 1.2108 - val_acc: 0.6693
# Epoch 97/200
#  - 1s - loss: 0.2190 - acc: 0.9308 - val_loss: 1.2128 - val_acc: 0.6693
# Epoch 98/200
#  - 1s - loss: 0.1935 - acc: 0.9209 - val_loss: 1.2140 - val_acc: 0.6693
# Epoch 99/200
#  - 1s - loss: 0.1869 - acc: 0.9308 - val_loss: 1.2212 - val_acc: 0.6693
# Epoch 100/200
#  - 1s - loss: 0.2078 - acc: 0.9249 - val_loss: 1.2309 - val_acc: 0.6693
# Epoch 101/200
#  - 1s - loss: 0.2115 - acc: 0.9368 - val_loss: 1.2428 - val_acc: 0.6772
# Epoch 102/200
#  - 1s - loss: 0.1949 - acc: 0.9328 - val_loss: 1.2514 - val_acc: 0.6772
# Epoch 103/200
#  - 1s - loss: 0.1483 - acc: 0.9486 - val_loss: 1.2564 - val_acc: 0.6693
# Epoch 104/200
#  - 1s - loss: 0.1698 - acc: 0.9407 - val_loss: 1.2619 - val_acc: 0.6693
# Epoch 105/200
#  - 1s - loss: 0.2019 - acc: 0.9308 - val_loss: 1.2647 - val_acc: 0.6693
# Epoch 106/200
#  - 1s - loss: 0.2233 - acc: 0.9130 - val_loss: 1.2651 - val_acc: 0.6772
# Epoch 107/200
#  - 1s - loss: 0.1920 - acc: 0.9328 - val_loss: 1.2607 - val_acc: 0.6772
# Epoch 108/200
#  - 1s - loss: 0.1695 - acc: 0.9387 - val_loss: 1.2574 - val_acc: 0.6693
# Epoch 109/200
#  - 1s - loss: 0.1942 - acc: 0.9249 - val_loss: 1.2561 - val_acc: 0.6614
# Epoch 110/200
#  - 1s - loss: 0.1915 - acc: 0.9328 - val_loss: 1.2507 - val_acc: 0.6614
# Epoch 111/200
#  - 1s - loss: 0.1959 - acc: 0.9269 - val_loss: 1.2475 - val_acc: 0.6614
# Epoch 112/200
#  - 1s - loss: 0.1948 - acc: 0.9289 - val_loss: 1.2452 - val_acc: 0.6614
# Epoch 113/200
#  - 1s - loss: 0.2106 - acc: 0.9249 - val_loss: 1.2442 - val_acc: 0.6614
# Epoch 114/200
#  - 1s - loss: 0.1910 - acc: 0.9269 - val_loss: 1.2479 - val_acc: 0.6614
# Epoch 115/200
#  - 1s - loss: 0.1733 - acc: 0.9407 - val_loss: 1.2506 - val_acc: 0.6614
# Epoch 116/200
#  - 1s - loss: 0.1611 - acc: 0.9506 - val_loss: 1.2566 - val_acc: 0.6614
# Epoch 117/200
#  - 1s - loss: 0.1999 - acc: 0.9289 - val_loss: 1.2615 - val_acc: 0.6614
# Epoch 118/200
#  - 1s - loss: 0.2219 - acc: 0.9071 - val_loss: 1.2664 - val_acc: 0.6535
# Epoch 119/200
#  - 1s - loss: 0.2133 - acc: 0.9150 - val_loss: 1.2722 - val_acc: 0.6535
# Epoch 120/200
#  - 1s - loss: 0.1845 - acc: 0.9308 - val_loss: 1.2755 - val_acc: 0.6535
# Epoch 121/200
#  - 1s - loss: 0.1758 - acc: 0.9229 - val_loss: 1.2806 - val_acc: 0.6535
# Epoch 122/200
#  - 1s - loss: 0.2207 - acc: 0.9190 - val_loss: 1.2832 - val_acc: 0.6535
# Epoch 123/200
#  - 1s - loss: 0.1826 - acc: 0.9447 - val_loss: 1.2857 - val_acc: 0.6535
# Epoch 124/200
#  - 1s - loss: 0.1645 - acc: 0.9506 - val_loss: 1.2876 - val_acc: 0.6535
# Epoch 125/200
#  - 1s - loss: 0.1759 - acc: 0.9427 - val_loss: 1.2875 - val_acc: 0.6535
# Epoch 126/200
#  - 1s - loss: 0.1958 - acc: 0.9249 - val_loss: 1.2856 - val_acc: 0.6535
# Epoch 127/200
#  - 1s - loss: 0.1803 - acc: 0.9348 - val_loss: 1.2859 - val_acc: 0.6535
# Epoch 128/200
#  - 1s - loss: 0.1874 - acc: 0.9209 - val_loss: 1.2839 - val_acc: 0.6535
# Epoch 129/200
#  - 1s - loss: 0.1617 - acc: 0.9486 - val_loss: 1.2836 - val_acc: 0.6535
# Epoch 130/200
#  - 1s - loss: 0.1568 - acc: 0.9447 - val_loss: 1.2835 - val_acc: 0.6535
# Epoch 131/200
#  - 1s - loss: 0.2151 - acc: 0.9289 - val_loss: 1.2852 - val_acc: 0.6535
# Epoch 132/200
#  - 1s - loss: 0.1788 - acc: 0.9308 - val_loss: 1.2830 - val_acc: 0.6535
# Epoch 133/200
#  - 1s - loss: 0.1562 - acc: 0.9526 - val_loss: 1.2833 - val_acc: 0.6535
# Epoch 134/200
#  - 1s - loss: 0.1949 - acc: 0.9348 - val_loss: 1.2822 - val_acc: 0.6535
# Epoch 135/200
#  - 1s - loss: 0.1886 - acc: 0.9328 - val_loss: 1.2805 - val_acc: 0.6535
# Epoch 136/200
#  - 1s - loss: 0.1729 - acc: 0.9308 - val_loss: 1.2823 - val_acc: 0.6535
# Epoch 137/200
#  - 1s - loss: 0.1980 - acc: 0.9289 - val_loss: 1.2838 - val_acc: 0.6535
# Epoch 138/200
#  - 1s - loss: 0.1699 - acc: 0.9466 - val_loss: 1.2841 - val_acc: 0.6535
# Epoch 139/200
#  - 1s - loss: 0.1922 - acc: 0.9328 - val_loss: 1.2852 - val_acc: 0.6535
# Epoch 140/200
#  - 1s - loss: 0.1855 - acc: 0.9229 - val_loss: 1.2853 - val_acc: 0.6535
# Epoch 141/200
#  - 1s - loss: 0.1837 - acc: 0.9427 - val_loss: 1.2867 - val_acc: 0.6535
# Epoch 142/200
#  - 1s - loss: 0.2003 - acc: 0.9407 - val_loss: 1.2856 - val_acc: 0.6535
# Epoch 143/200
#  - 1s - loss: 0.1778 - acc: 0.9308 - val_loss: 1.2873 - val_acc: 0.6535
# Epoch 144/200
#  - 1s - loss: 0.2309 - acc: 0.9269 - val_loss: 1.2897 - val_acc: 0.6535
# Epoch 145/200
#  - 1s - loss: 0.1890 - acc: 0.9348 - val_loss: 1.2905 - val_acc: 0.6535
# Epoch 146/200
#  - 1s - loss: 0.1948 - acc: 0.9387 - val_loss: 1.2892 - val_acc: 0.6614
# Epoch 147/200
#  - 1s - loss: 0.1633 - acc: 0.9368 - val_loss: 1.2908 - val_acc: 0.6535
# Epoch 148/200
#  - 1s - loss: 0.1841 - acc: 0.9368 - val_loss: 1.2919 - val_acc: 0.6535
# Epoch 149/200
#  - 1s - loss: 0.1886 - acc: 0.9348 - val_loss: 1.2910 - val_acc: 0.6535
# Epoch 150/200
#  - 1s - loss: 0.2011 - acc: 0.9229 - val_loss: 1.2915 - val_acc: 0.6535
# Epoch 151/200
#  - 1s - loss: 0.1899 - acc: 0.9289 - val_loss: 1.2910 - val_acc: 0.6535
# Epoch 152/200
#  - 1s - loss: 0.1704 - acc: 0.9466 - val_loss: 1.2902 - val_acc: 0.6535
# Epoch 153/200
#  - 1s - loss: 0.1847 - acc: 0.9348 - val_loss: 1.2905 - val_acc: 0.6535
# Epoch 154/200
#  - 1s - loss: 0.1763 - acc: 0.9407 - val_loss: 1.2901 - val_acc: 0.6535
# Epoch 155/200
#  - 1s - loss: 0.1771 - acc: 0.9289 - val_loss: 1.2908 - val_acc: 0.6535
# Epoch 156/200
#  - 1s - loss: 0.1745 - acc: 0.9486 - val_loss: 1.2899 - val_acc: 0.6535
# Epoch 157/200
#  - 1s - loss: 0.1874 - acc: 0.9348 - val_loss: 1.2899 - val_acc: 0.6535
# Epoch 158/200
#  - 1s - loss: 0.1849 - acc: 0.9348 - val_loss: 1.2886 - val_acc: 0.6535
# Epoch 159/200
#  - 1s - loss: 0.1877 - acc: 0.9387 - val_loss: 1.2904 - val_acc: 0.6535
# Epoch 160/200
#  - 1s - loss: 0.1582 - acc: 0.9387 - val_loss: 1.2908 - val_acc: 0.6535
# Epoch 161/200
#  - 1s - loss: 0.1824 - acc: 0.9289 - val_loss: 1.2897 - val_acc: 0.6535
# Epoch 162/200
#  - 1s - loss: 0.2044 - acc: 0.9328 - val_loss: 1.2894 - val_acc: 0.6535
# Epoch 163/200
#  - 1s - loss: 0.1821 - acc: 0.9269 - val_loss: 1.2877 - val_acc: 0.6535

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
model.save('VGG-ish_73.model')
